# %%
import random
from time import time
import pandas as pd

# %%
tamanho=1709
class no:
    def __init__(self,chave):
        self.chave=chave
        self.proximo = None
        self.anterior = None
        
class ListaEncadeada:
    def __init__(self):
        self.inicio = None
        
    def inserir(self,valor):
        novo = no(valor)
        if self.inicio == None:
            self.inicio = novo
            novo.anterior = self.inicio
        else:
            novo.proximo = self.inicio  
            self.inicio.anterior = novo  
            self.inicio = novo  

# Calasse Tabela Hash
class TabelaHash:
    _tamanho=103
    
    def __init__(self): # Metodo que instancia a classe
        self.indice = None
        self.valor = None
        self.tamanhoLista = 0 
        self.proximo = ListaEncadeada()
    
    def criarTabela(self,tamanho):
        tabela = []  
        for i in range(tamanho):
            tabela.append(TabelaHash())
        return tabela
    
    def inicializaTabela(self,tamanho):
        tabela = self.criarTabela(tamanho)  
        for i in range(tamanho):
            tabela[i].indice = i
            tabela[i].valor = None
            tabela[i].proximo = ListaEncadeada()
            self.tamanhoLista = 0
        return tabela

    def funcao_meio_quadrado(self, chave,tamanho):
        # Calcula o quadrado da chave e extrai o meio
        chave = int(''.join(str(ord(c)) for c in chave))  # Converte a chave para um número
        quadrado = chave ** 2
        quadrado_str = str(quadrado)
        meio = len(quadrado_str) // 2
        meio_quadrado = quadrado_str[meio - 2:meio + 2]  # Extrai 4 dígitos centrais
        return int(meio_quadrado) % tamanho

    def inserirTabela(self, tabela, elemento,tamanho):
        modIndice = self.funcao_meio_quadrado(elemento,tamanho)
        if tabela[modIndice].valor is None:
            tabela[modIndice].valor = elemento
        else:
            tabela[modIndice].proximo.inserir(elemento)
            tabela[modIndice].tamanhoLista +=1

# %%
def testarEficiencia(tamanhos_tabelas,lista_cidades):
    resultados = []
    colisoes = 0
    maior = 0
    for tam in tamanhos_tabelas:
        tabela_hash = TabelaHash()
        tabela = tabela_hash.inicializaTabela(tam)
        inicio = time()
        for cidade in lista_cidades:
            tabela_hash.inserirTabela(tabela,cidade,tam)
        fim = time()
        for i in range(tam):
            if tabela[i].valor is not None:
                print(f"Índice {i}: {tabela[i].valor}")
                no_atual = tabela[i].proximo.inicio
                while no_atual:
                    print(f"    Colisão -> {no_atual.chave}")
                    no_atual = no_atual.proximo
                    colisoes += 1
        for i in range(tam):
            if tabela[i].tamanhoLista > maior:
                maior = tabela[i].tamanhoLista
        resultados.append({
            "tamanho_tabela": tam,
            "colisoes": colisoes,
            "maior_lista_colisao": maior,
            "tempo_execucao": fim - inicio
        })
        colisoes = 0
        maior = 0
    return resultados
with open(r'C:\Users\rafam\Desktop\ED2\ED2\cidades.txt', 'r') as arquivo:

    lista_cidades = arquivo.readlines()
tamanhos_tabelas = [857,859,863,877,907,953,1709,1741,1759,1789,1801]
resultado = testarEficiencia(tamanhos_tabelas,lista_cidades)
resultado_df = pd.DataFrame(resultado)

resultado_df
# Out:
# Índice 1: Itambé do Mato Dentro
#
#     Colisão -> Rochedo de Minas
#
#     Colisão -> Martinho Campos
#
# Índice 2: Capinópolis
#
# Índice 3: Ituiutaba
#
#     Colisão -> São Francisco
#
# Índice 6: Ressaquinha
#
# Índice 7: Jacutinga
#
#     Colisão -> Santa Rita de Minas
#
# Índice 9: Belo Horizonte
#
#     Colisão -> Ladainha
#
# Índice 10: Chapada do Norte
#
# Índice 11: Funilândia
#
#     Colisão -> Veríssimo
#
#     Colisão -> Presidente Bernardes
#
# Índice 13: Monte Belo
#
# Índice 14: Igarapé
#
#     Colisão -> Piranga
#
# Índice 15: Senhora dos Remédios
#
# Índice 16: Campos Gerais
#
# Índice 17: Lima Duarte
#
# Índice 18: Felisburgo
#
#     Colisão -> Nanuque
#
#     Colisão -> Maripá de Minas
#
# Índice 20: Santana do Deserto
#
# Índice 21: Chiador
#
#     Colisão -> Monte Formoso
#
#     Colisão -> Curvelo
#
# Índice 22: Bom Sucesso
#
#     Colisão -> Santa Bárbara
#
# Índice 24: Bugre
#
#     Colisão -> Desterro de Entre Rios
#
# Índice 25: Araporã
#
#     Colisão -> Pingo-d'Água
#
#     Colisão -> Dores do Indaiá
#
# Índice 27: Conceição da Barra de Minas
#
# Índice 29: Sapucaí-Mirim
#
# Índice 30: Alfenas
#
# Índice 32: Ervália
#
#     Colisão -> Francisco Badaró
#
# Índice 34: Iraí de Minas
#
# Índice 36: Cristália
#
#     Colisão -> Prata
#
# Índice 39: Bonfim
#
# Índice 40: Ipanema
#
#     Colisão -> Jaboticatubas
#
# Índice 42: Patis
#
#     Colisão -> Santa Cruz de Salinas
#
# Índice 43: Virginópolis
#
# Índice 44: Itaobim
#
# Índice 45: Divino das Laranjeiras
#
#     Colisão -> Ouro Fino
#
# Índice 46: Coronel Murta
#
# Índice 47: Estrela do Indaiá
#
# Índice 48: Sacramento
#
# Índice 49: Leopoldina
#
# Índice 50: Setubinha
#
# Índice 52: Santa Juliana
#
# Índice 53: Oliveira Fortes
#
# Índice 54: Brasópolis
#
#     Colisão -> Santa Margarida
#
# Índice 55: Buritizeiro
#
# Índice 57: Monte Carmelo
#
# Índice 58: Novo Cruzeiro
#
# Índice 59: Pratinha
#
# Índice 60: Padre Carvalho
#
# Índice 63: Goiabeira
#
# Índice 64: Francisco Sá
#
# Índice 65: Rio Piracicaba
#
#     Colisão -> São Miguel do Anta
#
# Índice 67: Guaraciaba
#
# Índice 69: Silvianópolis
#
# Índice 70: São João da Lagoa
#
# Índice 71: Conceição das Pedras
#
#     Colisão -> Soledade de Minas
#
#     Colisão -> Lambari
#
# Índice 73: Carmo do Cajuru
#
#     Colisão -> Sete Lagoas
#
# Índice 74: Simonésia
#
# Índice 75: Campestre
#
#     Colisão -> Prudente de Morais
#
#     Colisão -> Guarani
#
#     Colisão -> Diogo de Vasconcelos
#
#     Colisão -> Congonhas
#
#     Colisão -> Caputira
#
# Índice 78: Santo Antônio do Aventureiro
#
# Índice 79: Ibertioga
#
#     Colisão -> Passa Tempo
#
# Índice 80: Jaíba
#
#     Colisão -> São Sebastião da Vargem Alegre
#
# Índice 83: Senador Firmino
#
# Índice 84: Jampruca
#
# Índice 88: Santa Bárbara do Tugúrio
#
# Índice 90: Passa-Vinte
#
#     Colisão -> Tocantins
#
# Índice 91: Itacarambi
#
# Índice 92: Serranópolis de Minas
#
# Índice 93: Arceburgo
#
#     Colisão -> Itaúna
#
# Índice 94: Araçuaí
#
#     Colisão -> Inhapim
#
# Índice 95: Acaiaca
#
# Índice 96: Santa Cruz do Escalvado
#
#     Colisão -> Sobrália
#
# Índice 98: Bandeira
#
#     Colisão -> Coromandel
#
# Índice 99: Pai Pedro
#
# Índice 100: Cabo Verde
#
# Índice 101: Brás Pires
#
#     Colisão -> Varzelândia
#
#     Colisão -> Córrego Novo
#
# Índice 102: Antônio Carlos
#
#     Colisão -> Careaçu
#
# Índice 103: Abadia dos Dourados
#
# Índice 104: Alvorada de Minas
#
# Índice 106: Extrema
#
#     Colisão -> Ilicínea
#
# Índice 109: Cambuí
#
#     Colisão -> São José do Divino
#
#     Colisão -> Santana do Paraíso
#
#     Colisão -> Pitangui
#
#     Colisão -> Jordânia
#
# Índice 111: Cascalho Rico
#
#     Colisão -> Faria Lemos
#
#     Colisão -> Espinosa
#
# Índice 114: Governador Valadares
#
# Índice 115: Buenópolis
#
#     Colisão -> Montezuma
#
#     Colisão -> Conceição dos Ouros
#
# Índice 116: Resplendor
#
# Índice 117: Dona Eusébia
#
# Índice 118: Bambuí
#
# Índice 119: Manhuaçu
#
#     Colisão -> Marilac
#
# Índice 123: Guidoval
#
# Índice 125: São João da Mata
#
# Índice 126: João Monlevade
#
#     Colisão -> Santa Helena de Minas
#
# Índice 127: Arantina
#
#     Colisão -> Passa-Quatro
#
# Índice 128: Alto Caparaó
#
#     Colisão -> São João do Paraíso
#
#     Colisão -> Ponto Chique
#
# Índice 133: Madre de Deus de Minas
#
# Índice 134: Abre-Campo
#
#     Colisão -> Romaria
#
# Índice 135: Ataléia
#
#     Colisão -> Cordislândia
#
# Índice 138: Carlos Chagas
#
#     Colisão -> Virgínia
#
#     Colisão -> Piedade do Rio Grande
#
# Índice 139: Ninheira
#
# Índice 142: Gouveia
#
# Índice 143: Argirita
#
#     Colisão -> Capitólio
#
# Índice 144: Doresópolis
#
# Índice 145: Claraval
#
# Índice 146: Santos Dumont
#
# Índice 147: Novo Oriente de Minas
#
# Índice 148: Itanhomi
#
# Índice 149: Belo Vale
#
#     Colisão -> Confins
#
# Índice 151: Contagem
#
# Índice 152: Pedro Teixeira
#
# Índice 153: Carmo do Rio Claro
#
#     Colisão -> Corinto
#
# Índice 154: Morada Nova de Minas
#
# Índice 156: Santa Efigênia de Minas
#
#     Colisão -> Vieiras
#
# Índice 157: São Vicente de Minas
#
# Índice 158: Vargem Alegre
#
# Índice 159: Rio Pomba
#
# Índice 160: Senhora de Oliveira
#
# Índice 162: Ibiracatu
#
# Índice 165: Alvarenga
#
# Índice 166: Arcos
#
# Índice 167: Caiana
#
#     Colisão -> Francisco Dumont
#
#     Colisão -> Carmésia
#
# Índice 168: Imbé de Minas
#
# Índice 169: Aracitaba
#
# Índice 171: Cambuquira
#
#     Colisão -> Pirapetinga
#
#     Colisão -> José Raydan
#
# Índice 173: Minduri
#
# Índice 174: Alto Rio Doce
#
#     Colisão -> Riachinho
#
# Índice 175: Santa Maria do Suaçuí
#
#     Colisão -> Serrania
#
#     Colisão -> Sarzedo
#
# Índice 178: Engenheiro Navarro
#
#     Colisão -> Florestal
#
# Índice 180: São Domingos do Prata
#
# Índice 181: Monjolos
#
# Índice 183: Vermelho Novo
#
# Índice 184: São João Nepomuceno
#
# Índice 187: Mateus Leme
#
# Índice 191: Urucuia
#
# Índice 192: São João del-Rei
#
# Índice 193: Capela Nova
#
# Índice 194: Santana do Riacho
#
# Índice 195: Coração de Jesus
#
#     Colisão -> Quartel Geral
#
#     Colisão -> Pescador
#
#     Colisão -> Japonvar
#
# Índice 197: Machado
#
#     Colisão -> Sericita
#
# Índice 198: Olhos-d'Água
#
# Índice 199: Barão de Monte Alto
#
#     Colisão -> Conquista
#
# Índice 200: Canápolis
#
# Índice 201: Itanhandu
#
# Índice 202: Araguari
#
#     Colisão -> Jacuí
#
# Índice 204: Frei Gaspar
#
#     Colisão -> Guapé
#
# Índice 205: Lavras
#
# Índice 206: São João do Oriente
#
# Índice 207: Lagamar
#
# Índice 208: Nova Resende
#
#     Colisão -> São João da Ponte
#
#     Colisão -> Santa Cruz de Minas
#
# Índice 210: Nazareno
#
#     Colisão -> Taiobeiras
#
# Índice 212: Itinga
#
#     Colisão -> Ouro Branco
#
#     Colisão -> Nova União
#
#     Colisão -> Nova Belém
#
# Índice 213: Augusto de Lima
#
# Índice 214: Antônio Dias
#
#     Colisão -> Piranguinho
#
# Índice 215: Espírito Santo do Dourado
#
#     Colisão -> Santo Antônio do Rio Abaixo
#
# Índice 217: Eugenópolis
#
# Índice 218: Silveirânia
#
# Índice 219: Estrela Dalva
#
# Índice 220: Berilo
#
#     Colisão -> Paineiras
#
#     Colisão -> Montes Claros
#
#     Colisão -> Jaguaraçu
#
#     Colisão -> Braúnas
#
# Índice 224: São José da Varginha
#
# Índice 225: São José do Jacuri
#
# Índice 226: Salinas
#
# Índice 227: Coimbra
#
#     Colisão -> São Gotardo
#
# Índice 230: Dom Joaquim
#
# Índice 231: Rosário da Limeira
#
# Índice 232: Ipatinga
#
# Índice 233: Ouro Verde de Minas
#
# Índice 234: Divisópolis
#
# Índice 235: Serra dos Aimorés
#
# Índice 236: Mata Verde
#
# Índice 237: Barroso
#
#     Colisão -> Rio Espera
#
# Índice 240: Itajubá
#
# Índice 241: Couto de Magalhães de Minas
#
#     Colisão -> Mutum
#
#     Colisão -> Jacinto
#
# Índice 242: Nacip Raydan
#
# Índice 243: Conceição do Rio Verde
#
#     Colisão -> Inconfidentes
#
# Índice 245: Alpercata
#
# Índice 246: Matozinhos
#
# Índice 247: Japaraíba
#
#     Colisão -> Nepomuceno
#
# Índice 248: Santana de Pirapama
#
# Índice 251: Naque
#
# Índice 252: Ribeirão Vermelho
#
#     Colisão -> São João Evangelista
#
# Índice 253: Ibituruna
#
# Índice 254: Luislândia
#
# Índice 255: Águas Vermelhas
#
#     Colisão -> Oliveira
#
# Índice 257: Cedro do Abaeté
#
#     Colisão -> Fervedouro
#
# Índice 259: Tupaciguara
#
# Índice 260: Açucena
#
# Índice 263: Pouso Alto
#
# Índice 264: Fortaleza de Minas
#
#     Colisão -> Uberaba
#
#     Colisão -> Pratápolis
#
# Índice 265: Felício dos Santos
#
#     Colisão -> Serra Azul de Minas
#
#     Colisão -> Presidente Olegário
#
# Índice 266: Itatiaiuçu
#
#     Colisão -> Liberdade
#
# Índice 269: Medeiros
#
# Índice 270: São Geraldo da Piedade
#
# Índice 271: Bom Repouso
#
#     Colisão -> Monsenhor Paulo
#
# Índice 272: Durandé
#
# Índice 273: Nova Serrana
#
# Índice 274: Divisa Alegre
#
#     Colisão -> Rio Vermelho
#
#     Colisão -> Dom Cavati
#
# Índice 276: Franciscópolis
#
# Índice 277: Ipiaçu
#
#     Colisão -> Perdigão
#
# Índice 278: Pedro Leopoldo
#
# Índice 279: Morro do Pilar
#
# Índice 280: Santo Antônio do Amparo
#
# Índice 282: Viçosa
#
# Índice 283: Jequitaí
#
#     Colisão -> Sardoá
#
#     Colisão -> Paracatu
#
# Índice 284: Bom Jesus do Amparo
#
# Índice 285: Claro dos Poções
#
#     Colisão -> Raposos
#
# Índice 287: Esmeraldas
#
# Índice 291: São Tomás de Aquino
#
# Índice 292: Buritis
#
# Índice 294: Ubaí
#
# Índice 296: Lagoa Santa
#
# Índice 297: Abaeté
#
# Índice 300: Santana do Jacaré
#
# Índice 301: Juiz de Fora
#
# Índice 302: Toledo
#
# Índice 303: Mato Verde
#
# Índice 304: Caratinga
#
# Índice 306: Delta
#
# Índice 308: Pirapora
#
# Índice 310: Catas Altas da Noruega
#
#     Colisão -> Taquaraçu de Minas
#
# Índice 311: Malacacheta
#
# Índice 312: Douradoquara
#
#     Colisão -> Santo Antônio do Itambé
#
# Índice 313: São Gonçalo do Rio Abaixo
#
#     Colisão -> Tombos
#
# Índice 314: Cássia
#
#     Colisão -> Rio Preto
#
# Índice 317: Albertina
#
#     Colisão -> Sabinópolis
#
#     Colisão -> Marliéria
#
#     Colisão -> Machacalis
#
# Índice 319: Coronel Xavier Chaves
#
#     Colisão -> Piumhi
#
# Índice 320: Candeias
#
#     Colisão -> Salto da Divisa
#
# Índice 321: Formiga
#
#     Colisão -> Rio do Prado
#
#     Colisão -> Reduto
#
#     Colisão -> Mariana
#
# Índice 322: Olaria
#
# Índice 323: Vazante
#
# Índice 325: Botelhos
#
#     Colisão -> Caxambu
#
# Índice 326: Pouso Alegre
#
# Índice 327: Itapecerica
#
#     Colisão -> São Bento Abade
#
# Índice 329: Araponga
#
# Índice 331: São Francisco de Paula
#
# Índice 332: Itapeva
#
# Índice 333: Patrocínio
#
# Índice 338: Catas Altas
#
# Índice 340: Urucânia
#
# Índice 341: Elói Mendes
#
#     Colisão -> Juramento
#
# Índice 343: Araxá
#
# Índice 344: Santa Maria de Itabira
#
# Índice 345: Josenópolis
#
# Índice 347: Comercinho
#
#     Colisão -> João Pinheiro
#
# Índice 348: São Sebastião do Anta
#
# Índice 349: Cristina
#
# Índice 350: Varjão de Minas
#
# Índice 351: Pains
#
#     Colisão -> São Gonçalo do Abaeté
#
# Índice 352: Bias Fortes
#
#     Colisão -> Santa Rita de Jacutinga
#
# Índice 356: Descoberto
#
# Índice 358: São João Batista do Glória
#
# Índice 363: Miraí
#
# Índice 364: Alterosa
#
# Índice 366: Padre Paraíso
#
#     Colisão -> Volta Grande
#
# Índice 369: Santa Vitória
#
#     Colisão -> Senador José Bento
#
# Índice 371: Juruaia
#
# Índice 375: Piedade dos Gerais
#
# Índice 376: Iapu
#
#     Colisão -> Senhora do Porto
#
# Índice 377: Simão Pereira
#
# Índice 378: Conceição da Aparecida
#
# Índice 380: Caldas
#
#     Colisão -> São Domingos das Dores
#
#     Colisão -> Manga
#
# Índice 381: Dom Viçoso
#
# Índice 383: Chácara
#
#     Colisão -> São João do Pacuí
#
# Índice 384: Santa Bárbara do Leste
#
# Índice 385: Guanhães
#
#     Colisão -> Santa Rosa da Serra
#
# Índice 386: Paraguaçu
#
#     Colisão -> Rodeiro
#
# Índice 387: Casa Grande
#
#     Colisão -> Cipotânea
#
# Índice 390: Ferros
#
# Índice 392: Conceição das Alagoas
#
# Índice 393: Bonfinópolis de Minas
#
# Índice 394: Angelândia
#
# Índice 395: Sem-Peixe
#
# Índice 396: Lassance
#
# Índice 397: Borda da Mata
#
#     Colisão -> Pequeri
#
#     Colisão -> Caeté
#
# Índice 400: Divisa Nova
#
#     Colisão -> Paraopeba
#
# Índice 401: Conselheiro Pena
#
#     Colisão -> Fronteira
#
# Índice 402: Tiradentes
#
# Índice 404: Congonhal
#
# Índice 406: Juatuba
#
#     Colisão -> Medina
#
# Índice 408: Ingaí
#
# Índice 409: Carvalhópolis
#
#     Colisão -> Paraisópolis
#
# Índice 411: Galileia
#
#     Colisão -> Munhoz
#
# Índice 414: Campanário
#
#     Colisão -> Oratórios
#
# Índice 418: Alvinópolis
#
#     Colisão -> Entre Folhas
#
# Índice 419: Patrocínio do Muriaé
#
# Índice 420: Carmópolis de Minas
#
#     Colisão -> Santa Luzia
#
# Índice 421: Santa Bárbara do Monte Verde
#
# Índice 422: Bom Jesus do Galho
#
#     Colisão -> Olímpio Noronha
#
# Índice 423: Ritápolis
#
# Índice 424: Turvolândia
#
# Índice 425: Ribeirão das Neves
#
# Índice 426: Cachoeira de Minas
#
#     Colisão -> Guarará
#
#     Colisão -> Fronteira dos Vales
#
# Índice 427: Barra Longa
#
#     Colisão -> São José da Safira
#
#     Colisão -> Conceição do Pará
#
#     Colisão -> Carangola
#
# Índice 428: Piedade de Ponte Nova
#
# Índice 429: Carmo da Cachoeira
#
# Índice 431: Caraí
#
#     Colisão -> Miradouro
#
#     Colisão -> Dores de Guanhães
#
# Índice 432: Carrancas
#
#     Colisão -> Pedrinópolis
#
#     Colisão -> Passabém
#
#     Colisão -> Matias Cardoso
#
# Índice 433: Conceição de Ipanema
#
#     Colisão -> Tabuleiro
#
# Índice 434: São Brás do Suaçuí
#
# Índice 436: Cachoeira de Pajeú
#
# Índice 439: Bonito de Minas
#
#     Colisão -> Poços de Caldas
#
# Índice 441: Bandeira do Sul
#
#     Colisão -> São Sebastião do Rio Preto
#
#     Colisão -> Monte Azul
#
#     Colisão -> Inhaúma
#
# Índice 447: Bicas
#
# Índice 448: Goianá
#
# Índice 450: Alagoa
#
# Índice 451: Marmelópolis
#
# Índice 452: Vespasiano
#
# Índice 454: Gurinhatã
#
# Índice 455: Icaraí de Minas
#
#     Colisão -> Itaú de Minas
#
# Índice 456: Fernandes Tourinho
#
#     Colisão -> Frutal
#
# Índice 458: São Sebastião do Rio Verde
#
# Índice 459: Pedra do Indaiá
#
# Índice 462: Itaipé
#
#     Colisão -> Santo Antônio do Monte
#
# Índice 465: Dores de Campos
#
#     Colisão -> Monte Alegre de Minas
#
# Índice 466: Onça de Pitangui
#
#     Colisão -> Rio Paranaíba
#
# Índice 468: Maria da Fé
#
#     Colisão -> São Lourenço
#
#     Colisão -> Poté
#
# Índice 470: Cônego Marinho
#
#     Colisão -> União de Minas
#
# Índice 471: Santo Antônio do Retiro
#
# Índice 472: Jequitibá
#
#     Colisão -> Mesquita
#
# Índice 474: Itabirinha
#
# Índice 476: Brasilândia de Minas
#
#     Colisão -> Rio Pardo de Minas
#
# Índice 478: Rio Acima
#
# Índice 479: Laranjal
#
#     Colisão -> Rubelita
#
# Índice 480: Itamonte
#
# Índice 481: Curral de Dentro
#
#     Colisão -> Itutinga
#
# Índice 482: Perdões
#
# Índice 483: Palmópolis
#
# Índice 485: Cristais
#
#     Colisão -> Teixeiras
#
# Índice 486: Cruzeiro da Fortaleza
#
#     Colisão -> Mar de Espanha
#
#     Colisão -> Datas
#
# Índice 487: Muzambinho
#
# Índice 488: Comendador Gomes
#
# Índice 489: Joaquim Felício
#
# Índice 492: Tocos do Moji
#
# Índice 493: Além Paraíba
#
# Índice 494: Água Comprida
#
# Índice 495: Verdelândia
#
# Índice 496: Inimutaba
#
#     Colisão -> Serra do Salitre
#
#     Colisão -> São Gonçalo do Pará
#
#     Colisão -> Ponto dos Volantes
#
# Índice 498: Caetanópolis
#
#     Colisão -> Itaverava
#
# Índice 499: Estrela do Sul
#
#     Colisão -> Paulistas
#
# Índice 500: Delfinópolis
#
#     Colisão -> Espera Feliz
#
# Índice 501: Conselheiro Lafaiete
#
# Índice 502: Aguanil
#
# Índice 503: Belo Oriente
#
#     Colisão -> Santa Fé de Minas
#
# Índice 504: Timóteo
#
# Índice 505: Ibiraci
#
# Índice 506: Betim
#
# Índice 507: Peçanha
#
# Índice 509: Cuparaque
#
# Índice 511: Piranguçu
#
#     Colisão -> Vargem Bonita
#
#     Colisão -> Teófilo Otoni
#
# Índice 512: Chalé
#
# Índice 513: Guimarânia
#
# Índice 518: Montalvânia
#
#     Colisão -> Pavão
#
# Índice 522: Mário Campos
#
# Índice 523: Crisólita
#
#     Colisão -> Itabira
#
# Índice 524: Bom Jesus da Penha
#
# Índice 525: Catuti
#
#     Colisão -> Igaratinga
#
#     Colisão -> Guiricema
#
# Índice 526: São Pedro dos Ferros
#
#     Colisão -> São Sebastião da Bela Vista
#
# Índice 527: Mathias Lobato
#
#     Colisão -> Santo Antônio do Jacinto
#
# Índice 529: Formoso
#
#     Colisão -> Senador Modestino Gonçalves
#
# Índice 531: Carbonita
#
# Índice 532: Água Boa
#
#     Colisão -> Cantagalo
#
# Índice 534: Guaranésia
#
# Índice 535: Ibitiúra de Minas
#
#     Colisão -> Lagoa Grande
#
# Índice 536: Andradas
#
# Índice 538: Lagoa dos Patos
#
# Índice 539: Lajinha
#
# Índice 541: Cataguases
#
#     Colisão -> Tapira
#
#     Colisão -> São Sebastião do Paraíso
#
#     Colisão -> Nova Módica
#
# Índice 542: Capim Branco
#
#     Colisão -> Cruzília
#
# Índice 543: Campo Florido
#
#     Colisão -> Tumiritinga
#
#     Colisão -> Fortuna de Minas
#
# Índice 546: Delfim Moreira
#
#     Colisão -> Planura
#
# Índice 547: Andrelândia
#
# Índice 548: Cana Verde
#
# Índice 553: Ewbank da Câmara
#
# Índice 555: Morro da Garça
#
# Índice 556: Centralina
#
#     Colisão -> Ipuiúna
#
# Índice 557: São Pedro da União
#
# Índice 561: Bueno Brandão
#
# Índice 564: Luisburgo
#
# Índice 565: Mantena
#
# Índice 566: Jesuânia
#
# Índice 569: Dores do Turvo
#
# Índice 570: Ijaci
#
# Índice 572: São José da Barra
#
# Índice 574: Ibiaí
#
# Índice 576: Paula Cândido
#
# Índice 577: Resende Costa
#
# Índice 578: São Francisco do Glória
#
# Índice 581: Baldim
#
# Índice 585: Ubá
#
# Índice 586: Crucilândia
#
#     Colisão -> São Thomé das Letras
#
#     Colisão -> Martins Soares
#
# Índice 587: Recreio
#
# Índice 588: São Pedro do Suaçuí
#
# Índice 589: Grão Mogol
#
# Índice 590: Camanducaia
#
# Índice 591: Itamogi
#
#     Colisão -> Veredinha
#
# Índice 592: Aiuruoca
#
#     Colisão -> Coluna
#
# Índice 593: Brasília de Minas
#
# Índice 594: Várzea da Palma
#
# Índice 595: Coronel Pacheco
#
# Índice 596: Pedra Dourada
#
#     Colisão -> Piracema
#
# Índice 600: Cachoeira Dourada
#
# Índice 601: Pará de Minas
#
# Índice 603: Itamarati de Minas
#
#     Colisão -> Prados
#
# Índice 604: Campo Azul
#
# Índice 606: Itamarandiba
#
#     Colisão -> Mamonas
#
#     Colisão -> Itueta
#
# Índice 608: Pirajuba
#
# Índice 609: Pintópolis
#
# Índice 610: Santana do Manhuaçu
#
# Índice 611: Frei Lagonegro
#
# Índice 614: Lagoa Formosa
#
# Índice 615: Itumirim
#
# Índice 616: Cordisburgo
#
#     Colisão -> Fruta de Leite
#
# Índice 618: Fama
#
#     Colisão -> Novorizonte
#
# Índice 619: São Sebastião do Oeste
#
# Índice 620: Águas Formosas
#
#     Colisão -> Piedade de Caratinga
#
# Índice 621: Santana dos Montes
#
# Índice 622: Mercês
#
#     Colisão -> Pocrane
#
# Índice 623: Poço Fundo
#
# Índice 625: Campina Verde
#
#     Colisão -> Córrego do Bom Jesus
#
#     Colisão -> Conceição do Mato Dentro
#
# Índice 626: Rio Doce
#
# Índice 627: Miravânia
#
# Índice 628: Capetinga
#
# Índice 630: Arapuá
#
#     Colisão -> Central de Minas
#
# Índice 631: Riacho dos Machados
#
#     Colisão -> Uruana de Minas
#
#     Colisão -> Três Marias
#
# Índice 634: Almenara
#
#     Colisão -> Araújos
#
#     Colisão -> Alto Jequitibá
#
# Índice 636: Cajuri
#
#     Colisão -> Tarumirim
#
#     Colisão -> Mirabela
#
# Índice 637: Aimorés
#
#     Colisão -> Três Pontas
#
# Índice 638: Barão de Cocais
#
#     Colisão -> Paiva
#
# Índice 639: Dionísio
#
# Índice 641: Santa Rita de Ibitipoca
#
# Índice 643: Indaiabira
#
#     Colisão -> Ouro Preto
#
# Índice 644: Santa Maria do Salto
#
# Índice 648: Divinolândia de Minas
#
# Índice 650: São Tiago
#
#     Colisão -> Serro
#
# Índice 651: Coqueiral
#
#     Colisão -> Pedra Bonita
#
# Índice 652: Campo Belo
#
# Índice 657: Cachoeira da Prata
#
#     Colisão -> Córrego Fundo
#
# Índice 658: Santana do Garambéu
#
# Índice 659: Campos Altos
#
# Índice 661: Tiros
#
# Índice 662: Camacho
#
#     Colisão -> Juvenília
#
#     Colisão -> Divinésia
#
# Índice 663: Manhumirim
#
# Índice 665: Araçaí
#
# Índice 666: Orizânia
#
#     Colisão -> São Gonçalo do Rio Preto
#
# Índice 668: Campo do Meio
#
# Índice 669: Belmiro Braga
#
#     Colisão -> Pimenta
#
#     Colisão -> Bom Jardim de Minas
#
# Índice 670: Biquinhas
#
# Índice 671: Palma
#
#     Colisão -> Pequi
#
# Índice 672: Piraúba
#
#     Colisão -> Três Corações
#
# Índice 673: Gonzaga
#
#     Colisão -> Serra da Saudade
#
# Índice 674: Matutina
#
# Índice 675: Uberlândia
#
# Índice 677: Chapada Gaúcha
#
#     Colisão -> Porto Firme
#
# Índice 678: Desterro do Melo
#
#     Colisão -> José Gonçalves de Minas
#
#     Colisão -> Iturama
#
# Índice 682: Canaã
#
#     Colisão -> Santa Rita do Itueto
#
#     Colisão -> Capelinha
#
# Índice 684: São Geraldo do Baixio
#
# Índice 687: Mendes Pimentel
#
# Índice 689: Serranos
#
# Índice 690: São Roque de Minas
#
# Índice 692: Alpinópolis
#
#     Colisão -> Patos de Minas
#
# Índice 693: Felixlândia
#
# Índice 694: Divinópolis
#
# Índice 697: Luminárias
#
# Índice 699: Arinos
#
#     Colisão -> Ponte Nova
#
#     Colisão -> Monte Sião
#
#     Colisão -> Carvalhos
#
# Índice 700: São Gonçalo do Sapucaí
#
# Índice 701: Astolfo Dutra
#
# Índice 702: São José da Lapa
#
#     Colisão -> Turmalina
#
# Índice 704: Natércia
#
# Índice 705: Cabeceira Grande
#
# Índice 706: Capitão Enéas
#
# Índice 707: São Romão
#
# Índice 711: Divino
#
# Índice 712: Raul Soares
#
# Índice 713: Itabirito
#
# Índice 715: Papagaios
#
# Índice 718: Coroaci
#
#     Colisão -> Tapiraí
#
# Índice 719: Capitão Andrade
#
# Índice 720: Leme do Prado
#
#     Colisão -> Santana da Vargem
#
#     Colisão -> Perdizes
#
# Índice 721: Bertópolis
#
# Índice 722: Guarda-Mor
#
#     Colisão -> Nova Lima
#
# Índice 723: São João do Manteninha
#
# Índice 724: Muriaé
#
# Índice 725: Itaguara
#
# Índice 726: Engenheiro Caldas
#
# Índice 727: Heliodora
#
# Índice 728: Gonçalves
#
# Índice 732: Coronel Fabriciano
#
#     Colisão -> Leandro Ferreira
#
# Índice 733: Carandaí
#
#     Colisão -> Periquito
#
#     Colisão -> Jenipapo de Minas
#
# Índice 734: Santo Antônio do Grama
#
#     Colisão -> Vargem Grande do Rio Pardo
#
# Índice 737: Passos
#
# Índice 739: Nova Ponte
#
# Índice 740: Antônio Prado de Minas
#
#     Colisão -> Seritinga
#
#     Colisão -> Guaxupé
#
# Índice 742: Nova Porteirinha
#
#     Colisão -> Pompéu
#
# Índice 743: Estiva
#
#     Colisão -> Santana de Cataguases
#
# Índice 744: Bela Vista de Minas
#
#     Colisão -> Lontra
#
#     Colisão -> Córrego Danta
#
#     Colisão -> Carmo de Minas
#
# Índice 745: Santa Rita do Sapucaí
#
#     Colisão -> Visconde do Rio Branco
#
# Índice 746: Carneirinho
#
# Índice 747: São Geraldo
#
# Índice 749: Guaraciama
#
# Índice 750: Rio Novo
#
# Índice 752: Congonhas do Norte
#
#     Colisão -> Virgem da Lapa
#
#     Colisão -> Varginha
#
#     Colisão -> Cristiano Otoni
#
# Índice 755: Rio Manso
#
# Índice 756: Lagoa Dourada
#
#     Colisão -> Sabará
#
# Índice 760: Ubaporanga
#
# Índice 761: Bocaina de Minas
#
#     Colisão -> Carmo do Paranaíba
#
# Índice 763: São José do Mantimento
#
# Índice 764: Ibirité
#
#     Colisão -> Limeira do Oeste
#
#     Colisão -> Lagoa da Prata
#
# Índice 765: Gameleiras
#
# Índice 767: Dom Bosco
#
# Índice 769: Alfredo Vasconcelos
#
# Índice 772: Joaíma
#
# Índice 773: Rio Casca
#
# Índice 774: Catuji
#
# Índice 776: Piau
#
# Índice 778: Nova Era
#
#     Colisão -> Santo Hipólito
#
# Índice 779: Matias Barbosa
#
# Índice 780: Diamantina
#
# Índice 784: Iguatama
#
# Índice 785: Janaúba
#
# Índice 786: Pedras de Maria da Cruz
#
# Índice 788: Brumadinho
#
#     Colisão -> Joanésia
#
#     Colisão -> Caranaíba
#
# Índice 790: Presidente Kubitschek
#
# Índice 791: São João do Manhuaçu
#
#     Colisão -> São José do Goiabal
#
# Índice 794: Ibiá
#
# Índice 795: Pedralva
#
#     Colisão -> São Joaquim de Bicas
#
# Índice 796: Aricanduva
#
#     Colisão -> São José do Alegre
#
#     Colisão -> Boa Esperança
#
# Índice 798: Jequitinhonha
#
#     Colisão -> Porteirinha
#
# Índice 799: São João das Missões
#
# Índice 800: Frei Inocêncio
#
#     Colisão -> Itapagipe
#
#     Colisão -> Itambacuri
#
# Índice 801: Barbacena
#
#     Colisão -> Virgolândia
#
#     Colisão -> Unaí
#
# Índice 803: Ipaba
#
# Índice 804: Dom Silvério
#
# Índice 805: Taparuba
#
# Índice 809: Grupiara
#
# Índice 810: Pedra Azul
#
#     Colisão -> Pedra do Anta
#
# Índice 812: Natalândia
#
# Índice 814: São Sebastião do Maranhão
#
# Índice 816: Amparo da Serra
#
#     Colisão -> Consolação
#
#     Colisão -> Berizal
#
# Índice 817: Baependi
#
# Índice 819: Bom Despacho
#
# Índice 821: Senador Cortes
#
# Índice 822: Luz
#
# Índice 823: São Félix de Minas
#
# Índice 824: Queluzito
#
#     Colisão -> Umburatiba
#
# Índice 826: Glaucilândia
#
#     Colisão -> Wenceslau Braz
# Índice 827: Areado
#
# Índice 828: Cláudio
#
#     Colisão -> Santa Rita de Caldas
#
# Índice 829: Materlândia
#
# Índice 830: Indianópolis
#
# Índice 831: Caparaó
#
# Índice 833: Monte Santo de Minas
#
#     Colisão -> São Francisco de Sales
#
# Índice 834: Carmo da Mata
#
#     Colisão -> Rubim
#
# Índice 838: Senador Amaral
#
# Índice 839: Entre Rios de Minas
#
#     Colisão -> Lamim
#
# Índice 843: Botumirim
#
# Índice 844: Januária
#
#     Colisão -> Presidente Juscelino
#
# Índice 846: Minas Novas
#
# Índice 848: Bocaiuva
#
#     Colisão -> Matipó
#
#     Colisão -> Campanha
#
# Índice 849: Jeceaba
#
#     Colisão -> Jequeri
#
# Índice 850: Moema
#
# Índice 851: Maravilhas
#
# Índice 852: Moeda
#
# Índice 856: Itacambira
#
# Índice 0: Capinópolis
#
#     Colisão -> Piranga
#
# Índice 1: Curvelo
#
# Índice 2: Campos Gerais
#
# Índice 3: São Francisco
#
# Índice 4: Nanuque
#
#     Colisão -> Ressaquinha
#
# Índice 5: Jacutinga
#
#     Colisão -> Veríssimo
#
# Índice 6: Bugre
#
# Índice 7: Presidente Bernardes
#
# Índice 8: Santa Bárbara
#
# Índice 9: Lima Duarte
#
#     Colisão -> Sapucaí-Mirim
#
# Índice 11: Monte Formoso
#
# Índice 13: Senhora dos Remédios
#
# Índice 14: Francisco Badaró
#
# Índice 15: Dores do Indaiá
#
# Índice 16: Bom Sucesso
#
# Índice 17: Pingo-d'Água
#
# Índice 18: Maripá de Minas
#
#     Colisão -> Santana do Deserto
#
# Índice 19: Chiador
#
# Índice 21: Araporã
#
#     Colisão -> Virginópolis
#
# Índice 22: Desterro de Entre Rios
#
#     Colisão -> Ipanema
#
# Índice 24: Alfenas
#
#     Colisão -> Ervália
#
# Índice 26: Itaobim
#
# Índice 27: Conceição da Barra de Minas
#
# Índice 28: Iraí de Minas
#
#     Colisão -> Prata
#
# Índice 30: Cristália
#
#     Colisão -> Santa Cruz de Salinas
#
#     Colisão -> Jaboticatubas
#
# Índice 31: Leopoldina
#
# Índice 32: Patis
#
#     Colisão -> Setubinha
#
#     Colisão -> Santa Margarida
#
# Índice 35: Divino das Laranjeiras
#
# Índice 37: Bonfim
#
# Índice 38: Padre Carvalho
#
# Índice 39: Oliveira Fortes
#
#     Colisão -> Pratinha
#
# Índice 41: Monte Carmelo
#
#     Colisão -> Ouro Fino
#
# Índice 42: Novo Cruzeiro
#
#     Colisão -> Sacramento
#
# Índice 45: Buritizeiro
#
#     Colisão -> Estrela do Indaiá
#
# Índice 46: Coronel Murta
#
#     Colisão -> Santa Juliana
#
# Índice 48: Francisco Sá
#
# Índice 49: São Miguel do Anta
#
# Índice 50: Brasópolis
#
# Índice 51: Guaraciaba
#
# Índice 53: Carmo do Cajuru
#
#     Colisão -> Silvianópolis
#
#     Colisão -> Rio Piracicaba
#
#     Colisão -> Congonhas
#
# Índice 57: Passa Tempo
#
#     Colisão -> Prudente de Morais
#
# Índice 59: Diogo de Vasconcelos
#
#     Colisão -> Soledade de Minas
#
# Índice 60: São João da Lagoa
#
# Índice 62: Jampruca
#
# Índice 63: Goiabeira
#
#     Colisão -> Sete Lagoas
#
# Índice 64: Simonésia
#
# Índice 65: Caputira
#
#     Colisão -> Senador Firmino
#
# Índice 67: Campestre
#
#     Colisão -> Conceição das Pedras
#
# Índice 68: Passa-Vinte
#
#     Colisão -> Tocantins
#
#     Colisão -> Santo Antônio do Aventureiro
#
# Índice 69: Ibertioga
#
#     Colisão -> Itacarambi
#
# Índice 71: Lambari
#
# Índice 72: Araçuaí
#
#     Colisão -> Jaíba
#
# Índice 75: Guarani
#
# Índice 76: Inhapim
#
#     Colisão -> São Sebastião da Vargem Alegre
#
# Índice 78: Santa Bárbara do Tugúrio
#
# Índice 80: Bandeira
#
#     Colisão -> Santa Cruz do Escalvado
#
# Índice 82: Serranópolis de Minas
#
# Índice 83: Acaiaca
#
#     Colisão -> Brás Pires
#
#     Colisão -> Arceburgo
#
# Índice 84: Coromandel
#
#     Colisão -> Ilicínea
#
# Índice 85: Itaúna
#
# Índice 86: Extrema
#
# Índice 88: Antônio Carlos
#
#     Colisão -> Sobrália
#
# Índice 90: Alvorada de Minas
#
#     Colisão -> Cabo Verde
#
# Índice 92: Careaçu
#
# Índice 93: Cambuí
#
#     Colisão -> Varzelândia
#
#     Colisão -> Córrego Novo
#
# Índice 94: Resplendor
#
# Índice 95: Cascalho Rico
#
#     Colisão -> Santana do Paraíso
#
#     Colisão -> Pai Pedro
#
#     Colisão -> Jordânia
#
#     Colisão -> Faria Lemos
#
#     Colisão -> Espinosa
#
# Índice 96: Bambuí
#
# Índice 97: Dona Eusébia
#
#     Colisão -> São José do Divino
#
#     Colisão -> Pitangui
#
# Índice 99: Abadia dos Dourados
#
#     Colisão -> Buenópolis
#
# Índice 101: Guidoval
#
# Índice 105: Manhuaçu
#
#     Colisão -> Marilac
#
# Índice 106: Governador Valadares
#
# Índice 107: Passa-Quatro
#
#     Colisão -> São João da Mata
#
# Índice 109: Montezuma
#
# Índice 112: Romaria
#
# Índice 113: Conceição dos Ouros
#
# Índice 115: Cordislândia
#
# Índice 116: Ponto Chique
#
#     Colisão -> São João do Paraíso
#
# Índice 118: Carlos Chagas
#
# Índice 121: Ninheira
#
# Índice 122: Abre-Campo
#
#     Colisão -> João Monlevade
#
# Índice 124: Santa Helena de Minas
#
# Índice 126: Piedade do Rio Grande
#
# Índice 127: Arantina
#
#     Colisão -> Claraval
#
# Índice 128: Alto Caparaó
#
#     Colisão -> Doresópolis
#
# Índice 129: Madre de Deus de Minas
#
# Índice 131: Argirita
#
#     Colisão -> Ataléia
#
# Índice 132: Virgínia
#
# Índice 134: Itanhomi
#
# Índice 135: Contagem
#
# Índice 137: Rio Pomba
#
#     Colisão -> São Vicente de Minas
#
# Índice 140: Vargem Alegre
#
# Índice 141: Belo Vale
#
#     Colisão -> Capitólio
#
# Índice 142: Gouveia
#
#     Colisão -> Morada Nova de Minas
#
# Índice 143: Novo Oriente de Minas
#
# Índice 144: Santos Dumont
#
# Índice 145: Confins
#
#     Colisão -> Francisco Dumont
#
# Índice 146: Senhora de Oliveira
#
# Índice 147: Carmésia
#
# Índice 148: Pedro Teixeira
#
#     Colisão -> Santa Efigênia de Minas
#
# Índice 149: Corinto
#
# Índice 151: Carmo do Rio Claro
#
# Índice 152: Vieiras
#
# Índice 153: Cambuquira
#
# Índice 156: Alto Rio Doce
#
#     Colisão -> Ibiracatu
#
# Índice 159: Pirapetinga
#
# Índice 160: Arcos
#
#     Colisão -> Imbé de Minas
#
# Índice 161: Caiana
#
# Índice 162: Riachinho
#
#     Colisão -> São João Nepomuceno
#
# Índice 163: Sarzedo
#
#     Colisão -> Serrania
#
# Índice 164: São Domingos do Prata
#
# Índice 165: Alvarenga
#
#     Colisão -> Minduri
#
# Índice 166: Florestal
#
# Índice 167: José Raydan
#
# Índice 169: Aracitaba
#
# Índice 171: Monjolos
#
#     Colisão -> Urucuia
#
# Índice 172: São João del-Rei
#
# Índice 173: Japonvar
#
# Índice 175: Machado
#
#     Colisão -> Santa Maria do Suaçuí
#
# Índice 178: Engenheiro Navarro
#
# Índice 179: Conquista
#
# Índice 180: Araguari
#
# Índice 183: Itanhandu
#
#     Colisão -> Vermelho Novo
#
#     Colisão -> Mateus Leme
#
# Índice 185: Capela Nova
#
# Índice 188: Canápolis
#
#     Colisão -> Guapé
#
# Índice 189: Pescador
#
#     Colisão -> Quartel Geral
#
# Índice 190: Jacuí
#
#     Colisão -> Taiobeiras
#
#     Colisão -> Santana do Riacho
#
#     Colisão -> Nova Resende
#
# Índice 191: Barão de Monte Alto
#
# Índice 192: Olhos-d'Água
#
#     Colisão -> São João da Ponte
#
# Índice 193: Augusto de Lima
#
#     Colisão -> Sericita
#
#     Colisão -> Coração de Jesus
#
# Índice 194: Nova Belém
#
# Índice 195: Lavras
#
# Índice 196: Santa Cruz de Minas
#
# Índice 200: São João do Oriente
#
# Índice 202: Berilo
#
#     Colisão -> Silveirânia
#
#     Colisão -> Montes Claros
#
#     Colisão -> Frei Gaspar
#
# Índice 203: Espírito Santo do Dourado
#
#     Colisão -> Santo Antônio do Rio Abaixo
#
#     Colisão -> Eugenópolis
#
# Índice 204: Nova União
#
# Índice 206: Nazareno
#
# Índice 207: Estrela Dalva
#
#     Colisão -> Lagamar
#
# Índice 208: Ouro Branco
#
# Índice 209: São José do Jacuri
#
# Índice 210: Piranguinho
#
# Índice 212: Antônio Dias
#
#     Colisão -> Itinga
#
# Índice 214: Mata Verde
#
# Índice 216: Braúnas
#
# Índice 217: Coimbra
#
#     Colisão -> São Gotardo
#
# Índice 218: Ipatinga
#
#     Colisão -> Paineiras
#
#     Colisão -> Jaguaraçu
#
# Índice 219: Rosário da Limeira
#
# Índice 220: Divisópolis
#
#     Colisão -> Salinas
#
#     Colisão -> Dom Joaquim
#
# Índice 221: Inconfidentes
#
#     Colisão -> Mutum
#
# Índice 222: São José da Varginha
#
# Índice 225: Nepomuceno
#
# Índice 227: Japaraíba
#
#     Colisão -> Serra dos Aimorés
#
#     Colisão -> Rio Espera
#
# Índice 229: Barroso
#
#     Colisão -> Ouro Verde de Minas
#
# Índice 230: São João Evangelista
#
# Índice 231: Conceição do Rio Verde
#
# Índice 232: Nacip Raydan
#
#     Colisão -> Ribeirão Vermelho
#
# Índice 236: Santana de Pirapama
#
# Índice 238: Matozinhos
#
# Índice 239: Alpercata
#
#     Colisão -> Jacinto
#
#     Colisão -> Couto de Magalhães de Minas
#
# Índice 240: Itajubá
#
#     Colisão -> Luislândia
#
# Índice 241: Águas Vermelhas
#
# Índice 242: Uberaba
#
# Índice 243: Fervedouro
#
# Índice 245: Cedro do Abaeté
#
#     Colisão -> Serra Azul de Minas
#
#     Colisão -> Presidente Olegário
#
# Índice 248: Itatiaiuçu
#
# Índice 249: Pouso Alto
#
# Índice 251: Ibituruna
#
#     Colisão -> Oliveira
#
#     Colisão -> Naque
#
# Índice 252: Açucena
#
# Índice 257: Felício dos Santos
#
#     Colisão -> Tupaciguara
#
#     Colisão -> Monsenhor Paulo
#
# Índice 258: Durandé
#
#     Colisão -> São Geraldo da Piedade
#
# Índice 259: Bom Repouso
#
#     Colisão -> Ipiaçu
#
# Índice 261: Medeiros
#
#     Colisão -> Sardoá
#
# Índice 262: Fortaleza de Minas
#
#     Colisão -> Liberdade
#
# Índice 264: Pedro Leopoldo
#
#     Colisão -> Pratápolis
#
# Índice 266: Dom Cavati
#
#     Colisão -> Viçosa
#
#     Colisão -> Rio Vermelho
#
# Índice 267: Esmeraldas
#
#     Colisão -> Paracatu
#
#     Colisão -> Nova Serrana
#
# Índice 268: Franciscópolis
#
#     Colisão -> Santo Antônio do Amparo
#
# Índice 269: São Tomás de Aquino
#
# Índice 271: Claro dos Poções
#
# Índice 272: Bom Jesus do Amparo
#
#     Colisão -> Divisa Alegre
#
# Índice 273: Perdigão
#
#     Colisão -> Raposos
#
# Índice 275: Abaeté
#
#     Colisão -> Jequitaí
#
# Índice 279: Morro do Pilar
#
# Índice 282: Lagoa Santa
#
# Índice 286: Ubaí
#
# Índice 288: Taquaraçu de Minas
#
# Índice 290: Buritis
#
#     Colisão -> Santo Antônio do Itambé
#
# Índice 291: São Gonçalo do Rio Abaixo
#
# Índice 293: Juiz de Fora
#
#     Colisão -> Tombos
#
# Índice 294: Toledo
#
# Índice 295: Albertina
#
# Índice 298: Catas Altas da Noruega
#
#     Colisão -> Pirapora
#
#     Colisão -> Delta
#
# Índice 299: Coronel Xavier Chaves
#
# Índice 300: Santana do Jacaré
#
# Índice 301: Formiga
#
#     Colisão -> Mato Verde
#
# Índice 304: Candeias
#
#     Colisão -> Olaria
#
#     Colisão -> Douradoquara
#
#     Colisão -> Caratinga
#
# Índice 305: Malacacheta
#
#     Colisão -> Sabinópolis
#
#     Colisão -> Marliéria
#
# Índice 307: São Bento Abade
#
# Índice 308: Cássia
#
#     Colisão -> Salto da Divisa
#
#     Colisão -> Pouso Alegre
#
# Índice 311: Botelhos
#
#     Colisão -> Mariana
#
#     Colisão -> Itapecerica
#
# Índice 313: Vazante
#
# Índice 314: Rio Preto
#
# Índice 315: Machacalis
#
#     Colisão -> Piumhi
#
# Índice 317: Araponga
#
#     Colisão -> Rio do Prado
#
#     Colisão -> Caxambu
#
# Índice 319: Reduto
#
# Índice 321: Araxá
#
#     Colisão -> São Francisco de Paula
#
# Índice 325: Patrocínio
#
# Índice 327: Elói Mendes
#
# Índice 328: Itapeva
#
# Índice 329: São Gonçalo do Abaeté
#
# Índice 330: Varjão de Minas
#
# Índice 332: São Sebastião do Anta
#
# Índice 334: Catas Altas
#
# Índice 335: Josenópolis
#
# Índice 336: Urucânia
#
# Índice 337: João Pinheiro
#
# Índice 341: Comercinho
#
#     Colisão -> Juramento
#
# Índice 342: Descoberto
#
#     Colisão -> Santa Rita de Jacutinga
#
# Índice 344: Santa Maria de Itabira
#
# Índice 345: Cristina
#
# Índice 346: Bias Fortes
#
# Índice 347: Pains
#
#     Colisão -> Senador José Bento
#
# Índice 351: Miraí
#
# Índice 352: Padre Paraíso
#
# Índice 356: São João Batista do Glória
#
#     Colisão -> Volta Grande
#
# Índice 357: Juruaia
#
# Índice 359: Simão Pereira
#
# Índice 360: Conceição da Aparecida
#
# Índice 361: Piedade dos Gerais
#
# Índice 362: Alterosa
#
# Índice 363: Dom Viçoso
#
#     Colisão -> Santa Vitória
#
# Índice 364: Rodeiro
#
# Índice 365: Guanhães
#
# Índice 366: Paraguaçu
#
# Índice 367: Chácara
#
#     Colisão -> Cipotânea
#
# Índice 369: São João do Pacuí
#
# Índice 370: Caldas
#
#     Colisão -> Manga
#
#     Colisão -> Iapu
#
#     Colisão -> Ferros
#
# Índice 373: Casa Grande
#
# Índice 375: Borda da Mata
#
# Índice 376: Senhora do Porto
#
# Índice 378: Lassance
#
# Índice 379: Sem-Peixe
#
# Índice 380: São Domingos das Dores
#
# Índice 381: Caeté
#
# Índice 382: Tiradentes
#
# Índice 384: Medina
#
#     Colisão -> Santa Bárbara do Leste
#
# Índice 385: Santa Rosa da Serra
#
# Índice 387: Conselheiro Pena
#
# Índice 388: Angelândia
#
#     Colisão -> Paraopeba
#
#     Colisão -> Ingaí
#
# Índice 389: Bonfinópolis de Minas
#
#     Colisão -> Galileia
#
# Índice 390: Divisa Nova
#
# Índice 391: Carvalhópolis
#
#     Colisão -> Pequeri
#
# Índice 392: Conceição das Alagoas
#
#     Colisão -> Congonhal
#
# Índice 394: Campanário
#
# Índice 397: Fronteira
#
# Índice 399: Santa Bárbara do Monte Verde
#
# Índice 400: Alvinópolis
#
# Índice 401: Paraisópolis
#
#     Colisão -> Ritápolis
#
# Índice 402: Carmópolis de Minas
#
# Índice 406: Juatuba
#
# Índice 407: Carmo da Cachoeira
#
#     Colisão -> Munhoz
#
#     Colisão -> Conceição do Pará
#
# Índice 409: Ribeirão das Neves
#
# Índice 410: Turvolândia
#
# Índice 411: São José da Safira
#
# Índice 412: Entre Folhas
#
#     Colisão -> Pedrinópolis
#
# Índice 413: Patrocínio do Muriaé
#
# Índice 414: Carrancas
#
#     Colisão -> Oratórios
#
# Índice 417: Carangola
#
#     Colisão -> Miradouro
#
# Índice 418: Cachoeira de Pajeú
#
#     Colisão -> Santa Luzia
#
#     Colisão -> Piedade de Ponte Nova
#
#     Colisão -> Olímpio Noronha
#
# Índice 419: Bonito de Minas
#
# Índice 420: Bom Jesus do Galho
#
#     Colisão -> Passabém
#
# Índice 421: Monte Azul
#
# Índice 422: Cachoeira de Minas
#
#     Colisão -> Matias Cardoso
#
#     Colisão -> Fronteira dos Vales
#
# Índice 423: Dores de Guanhães
#
# Índice 424: Guarará
#
# Índice 425: Bandeira do Sul
#
#     Colisão -> São Sebastião do Rio Preto
#
#     Colisão -> Poços de Caldas
#
#     Colisão -> Caraí
#
#     Colisão -> Barra Longa
#
# Índice 429: Bicas
#
#     Colisão -> Tabuleiro
#
#     Colisão -> Inhaúma
#
# Índice 431: Conceição de Ipanema
#
# Índice 434: São Brás do Suaçuí
#
# Índice 438: Alagoa
#
# Índice 440: Itaipé
#
# Índice 443: Icaraí de Minas
#
# Índice 444: Goianá
#
# Índice 445: Itaú de Minas
#
# Índice 447: Marmelópolis
#
# Índice 448: Onça de Pitangui
#
#     Colisão -> São Lourenço
#
# Índice 449: Santo Antônio do Retiro
#
# Índice 450: Fernandes Tourinho
#
# Índice 451: Dores de Campos
#
# Índice 452: Vespasiano
#
# Índice 453: Pedra do Indaiá
#
# Índice 454: Frutal
#
#     Colisão -> São Sebastião do Rio Verde
#
#     Colisão -> Mesquita
#
#     Colisão -> Gurinhatã
#
# Índice 456: Cônego Marinho
#
#     Colisão -> Jequitibá
#
# Índice 457: Monte Alegre de Minas
#
# Índice 460: Maria da Fé
#
#     Colisão -> Santo Antônio do Monte
#
#     Colisão -> Rio Paranaíba
#
# Índice 462: Brasilândia de Minas
#
#     Colisão -> União de Minas
#
#     Colisão -> Rio Pardo de Minas
#
# Índice 464: Rio Acima
#
# Índice 466: Itabirinha
#
#     Colisão -> Poté
#
#     Colisão -> Perdões
#
#     Colisão -> Itamonte
#
# Índice 469: Cristais
#
#     Colisão -> Muzambinho
#
# Índice 471: Laranjal
#
# Índice 473: Além Paraíba
#
#     Colisão -> Palmópolis
#
# Índice 476: Tocos do Moji
#
# Índice 477: Rubelita
#
# Índice 478: Datas
#
# Índice 479: Curral de Dentro
#
# Índice 480: Comendador Gomes
#
#     Colisão -> Mar de Espanha
#
#     Colisão -> Delfinópolis
#
# Índice 481: Itutinga
#
#     Colisão -> Verdelândia
#
#     Colisão -> Joaquim Felício
#
# Índice 482: Cruzeiro da Fortaleza
#
#     Colisão -> Inimutaba
#
# Índice 483: Teixeiras
#
# Índice 485: Ibiraci
#
# Índice 486: Aguanil
#
# Índice 490: Ponto dos Volantes
#
#     Colisão -> Serra do Salitre
#
#     Colisão -> São Gonçalo do Pará
#
# Índice 491: Belo Oriente
#
#     Colisão -> Teófilo Otoni
#
#     Colisão -> Peçanha
#
#     Colisão -> Estrela do Sul
#
# Índice 492: Água Comprida
#
# Índice 493: Conselheiro Lafaiete
#
# Índice 494: Caetanópolis
#
# Índice 495: Guimarânia
#
#     Colisão -> Santa Fé de Minas
#
#     Colisão -> Piranguçu
#
# Índice 496: Itaverava
#
#     Colisão -> Montalvânia
#
# Índice 497: Vargem Bonita
#
# Índice 499: Paulistas
#
# Índice 500: Espera Feliz
#
# Índice 502: Chalé
#
#     Colisão -> Timóteo
#
# Índice 504: Betim
#
# Índice 505: Crisólita
#
#     Colisão -> Itabira
#
# Índice 508: Pavão
#
# Índice 509: Catuti
#
#     Colisão -> Mathias Lobato
#
#     Colisão -> Cuparaque
#
# Índice 510: Mário Campos
#
# Índice 511: Santo Antônio do Jacinto
#
# Índice 513: Guiricema
#
# Índice 514: Bom Jesus da Penha
#
#     Colisão -> São Sebastião da Bela Vista
#
# Índice 515: Lagoa Grande
#
# Índice 516: Cantagalo
#
# Índice 519: Formoso
#
#     Colisão -> Ibitiúra de Minas
#
# Índice 520: Capim Branco
#
# Índice 521: Igaratinga
#
# Índice 522: São Pedro dos Ferros
#
# Índice 523: Nova Módica
#
#     Colisão -> São Sebastião do Paraíso
#
# Índice 525: Carbonita
#
#     Colisão -> Tapira
#
# Índice 527: Senador Modestino Gonçalves
#
# Índice 530: Água Boa
#
#     Colisão -> Lagoa dos Patos
#
#     Colisão -> Guaranésia
#
#     Colisão -> Delfim Moreira
#
#     Colisão -> Cana Verde
#
#     Colisão -> Andradas
#
# Índice 531: Fortuna de Minas
#
# Índice 532: Cruzília
#
#     Colisão -> Planura
#
# Índice 533: Campo Florido
#
# Índice 535: Ewbank da Câmara
#
# Índice 537: Lajinha
#
#     Colisão -> São Pedro da União
#
# Índice 539: Cataguases
#
# Índice 543: Tumiritinga
#
# Índice 544: Centralina
#
# Índice 546: Luisburgo
#
# Índice 547: Andrelândia
#
# Índice 551: Dores do Turvo
#
# Índice 552: Ipuiúna
#
# Índice 553: Morro da Garça
#
# Índice 558: Ijaci
#
#     Colisão -> Jesuânia
#
# Índice 560: São José da Barra
#
# Índice 561: Bueno Brandão
#
# Índice 565: Mantena
#
# Índice 568: Ibiaí
#
#     Colisão -> Paula Cândido
#
# Índice 571: Resende Costa
#
# Índice 572: Aiuruoca
#
#     Colisão -> Crucilândia
#
# Índice 573: Baldim
#
# Índice 575: Ubá
#
# Índice 576: Martins Soares
#
# Índice 578: São Francisco do Glória
#
# Índice 579: Itamogi
#
#     Colisão -> Veredinha
#
# Índice 580: Piracema
#
#     Colisão -> Várzea da Palma
#
# Índice 581: Recreio
#
# Índice 582: São Pedro do Suaçuí
#
# Índice 584: Cachoeira Dourada
#
#     Colisão -> Camanducaia
#
# Índice 585: Brasília de Minas
#
# Índice 586: São Thomé das Letras
#
# Índice 589: Grão Mogol
#
#     Colisão -> Prados
#
#     Colisão -> Itamarati de Minas
#
# Índice 591: Pará de Minas
#
# Índice 592: Coluna
#
#     Colisão -> Mamonas
#
# Índice 593: Coronel Pacheco
#
# Índice 594: Itueta
#
#     Colisão -> Pedra Dourada
#
# Índice 598: Novorizonte
#
# Índice 599: Frei Lagonegro
#
#     Colisão -> Pintópolis
#
# Índice 600: Campo Azul
#
# Índice 602: Cordisburgo
#
# Índice 604: Fruta de Leite
#
#     Colisão -> Pirajuba
#
# Índice 605: Campina Verde
#
# Índice 606: Itamarandiba
#
#     Colisão -> Lagoa Formosa
#
# Índice 607: Itumirim
#
#     Colisão -> São Sebastião do Oeste
#
# Índice 608: Piedade de Caratinga
#
#     Colisão -> Rio Doce
#
# Índice 610: Fama
#
#     Colisão -> Santana do Manhuaçu
#
# Índice 613: Santana dos Montes
#
# Índice 614: Central de Minas
#
#     Colisão -> Mercês
#
# Índice 615: Conceição do Mato Dentro
#
# Índice 616: Alto Jequitibá
#
#     Colisão -> Capetinga
#
#     Colisão -> Araújos
#
# Índice 617: Poço Fundo
#
# Índice 619: Três Marias
#
# Índice 620: Águas Formosas
#
#     Colisão -> Pocrane
#
#     Colisão -> Mirabela
#
# Índice 621: Miravânia
#
#     Colisão -> Três Pontas
#
#     Colisão -> Santa Rita de Ibitipoca
#
# Índice 622: Almenara
#
#     Colisão -> Cajuri
#
# Índice 623: Aimorés
#
#     Colisão -> Córrego do Bom Jesus
#
# Índice 624: Paiva
#
# Índice 625: Riacho dos Machados
#
# Índice 626: Arapuá
#
# Índice 627: Dionísio
#
#     Colisão -> Uruana de Minas
#
# Índice 628: Santa Maria do Salto
#
# Índice 630: Barão de Cocais
#
# Índice 631: Indaiabira
#
# Índice 636: Tarumirim
#
# Índice 637: Cachoeira da Prata
#
# Índice 638: Campo Belo
#
#     Colisão -> Divinolândia de Minas
#
# Índice 639: Ouro Preto
#
# Índice 641: Tiros
#
# Índice 643: Córrego Fundo
#
# Índice 644: São Tiago
#
# Índice 646: Orizânia
#
# Índice 647: Coqueiral
#
# Índice 648: Santana do Garambéu
#
#     Colisão -> Serro
#
#     Colisão -> São Gonçalo do Rio Preto
#
# Índice 649: Campos Altos
#
#     Colisão -> Pedra Bonita
#
# Índice 650: Divinésia
#
# Índice 651: Belmiro Braga
#
# Índice 652: Piraúba
#
# Índice 653: Serra da Saudade
#
# Índice 655: Araçaí
#
#     Colisão -> Uberlândia
#
#     Colisão -> Gonzaga
#
# Índice 656: Camacho
#
# Índice 657: Pequi
#
# Índice 658: Iturama
#
# Índice 659: Bom Jardim de Minas
#
#     Colisão -> Palma
#
# Índice 660: Campo do Meio
#
#     Colisão -> José Gonçalves de Minas
#
# Índice 661: Chapada Gaúcha
#
# Índice 662: Biquinhas
#
#     Colisão -> Juvenília
#
# Índice 663: Manhumirim
#
# Índice 664: Matutina
#
#     Colisão -> Três Corações
#
# Índice 667: Pimenta
#
# Índice 668: Canaã
#
# Índice 669: Serranos
#
# Índice 670: Capelinha
#
# Índice 671: Porto Firme
#
# Índice 674: Alpinópolis
#
# Índice 678: Desterro do Melo
#
#     Colisão -> Santa Rita do Itueto
#
# Índice 679: Luminárias
#
# Índice 680: Patos de Minas
#
# Índice 681: Carvalhos
#
# Índice 682: Turmalina
#
# Índice 684: São Geraldo do Baixio
#
#     Colisão -> São José da Lapa
#
# Índice 685: Astolfo Dutra
#
# Índice 686: Divinópolis
#
# Índice 687: Mendes Pimentel
#
# Índice 690: São Roque de Minas
#
# Índice 691: Ponte Nova
#
# Índice 692: Capitão Enéas
#
#     Colisão -> Natércia
#
# Índice 693: Arinos
#
#     Colisão -> Monte Sião
#
#     Colisão -> Felixlândia
#
#     Colisão -> Cabeceira Grande
#
# Índice 696: São Gonçalo do Sapucaí
#
# Índice 701: Divino
#
#     Colisão -> São Romão
#
#     Colisão -> Papagaios
#
# Índice 702: Guarda-Mor
#
#     Colisão -> Tapiraí
#
# Índice 705: Itabirito
#
# Índice 706: Engenheiro Caldas
#
# Índice 708: Raul Soares
#
# Índice 709: São João do Manteninha
#
# Índice 710: Muriaé
#
# Índice 711: Bertópolis
#
# Índice 714: Coroaci
#
# Índice 715: Capitão Andrade
#
#     Colisão -> Periquito
#
# Índice 717: Jenipapo de Minas
#
# Índice 718: Perdizes
#
# Índice 719: Heliodora
#
# Índice 720: Leandro Ferreira
#
#     Colisão -> Santana da Vargem
#
#     Colisão -> Leme do Prado
#
# Índice 722: Antônio Prado de Minas
#
#     Colisão -> Seritinga
#
#     Colisão -> Nova Lima
#
# Índice 723: Carandaí
#
#     Colisão -> Passos
#
#     Colisão -> Itaguara
#
# Índice 724: Gonçalves
#
# Índice 726: Carmo de Minas
#
#     Colisão -> Santo Antônio do Grama
#
# Índice 727: Estiva
#
# Índice 728: Pompéu
#
# Índice 730: Coronel Fabriciano
#
#     Colisão -> Rio Novo
#
#     Colisão -> Lontra
#
# Índice 731: Santana de Cataguases
#
# Índice 732: Córrego Danta
#
#     Colisão -> Vargem Grande do Rio Pardo
#
#     Colisão -> Guaxupé
#
# Índice 733: Visconde do Rio Branco
#
# Índice 735: Santa Rita do Sapucaí
#
# Índice 737: Nova Ponte
#
#     Colisão -> Rio Manso
#
# Índice 738: Bela Vista de Minas
#
#     Colisão -> Virgem da Lapa
#
# Índice 739: São Geraldo
#
# Índice 741: Bocaina de Minas
#
#     Colisão -> Guaraciama
#
# Índice 742: Carneirinho
#
#     Colisão -> Nova Porteirinha
#
# Índice 744: Congonhas do Norte
#
#     Colisão -> Ibirité
#
#     Colisão -> Cristiano Otoni
#
# Índice 745: Gameleiras
#
# Índice 746: Lagoa Dourada
#
#     Colisão -> Varginha
#
#     Colisão -> Limeira do Oeste
#
# Índice 750: Sabará
#
#     Colisão -> Ubaporanga
#
# Índice 751: Alfredo Vasconcelos
#
# Índice 755: Dom Bosco
#
#     Colisão -> Rio Casca
#
# Índice 758: Joaíma
#
# Índice 761: Carmo do Paranaíba
#
# Índice 762: Diamantina
#
#     Colisão -> Nova Era
#
# Índice 763: São José do Mantimento
#
# Índice 764: Catuji
#
#     Colisão -> Lagoa da Prata
#
# Índice 768: Joanésia
#
# Índice 770: Brumadinho
#
# Índice 772: Piau
#
# Índice 774: Santo Hipólito
#
# Índice 775: Janaúba
#
# Índice 776: Boa Esperança
#
# Índice 777: Pedralva
#
# Índice 779: Matias Barbosa
#
# Índice 780: Iguatama
#
#     Colisão -> Presidente Kubitschek
#
# Índice 781: Unaí
#
# Índice 782: Caranaíba
#
#     Colisão -> Frei Inocêncio
#
# Índice 783: São João do Manhuaçu
#
# Índice 786: Pedras de Maria da Cruz
#
# Índice 787: São Joaquim de Bicas
#
#     Colisão -> Virgolândia
#
# Índice 789: Barbacena
#
#     Colisão -> São José do Goiabal
#
#     Colisão -> São João das Missões
#
# Índice 790: Aricanduva
#
# Índice 792: Ibiá
#
#     Colisão -> São José do Alegre
#
#     Colisão -> Itapagipe
#
# Índice 794: Jequitinhonha
#
#     Colisão -> Porteirinha
#
# Índice 796: Berizal
#
#     Colisão -> Pedra Azul
#
# Índice 797: Grupiara
#
#     Colisão -> Ipaba
#
# Índice 798: Dom Silvério
#
#     Colisão -> São Sebastião do Maranhão
#
#     Colisão -> Itambacuri
#
# Índice 801: Bom Despacho
#
# Índice 803: Baependi
#
# Índice 804: Consolação
#
#     Colisão -> Queluzito
#
#     Colisão -> Pedra do Anta
#
# Índice 805: Taparuba
#
# Índice 806: Luz
#
#     Colisão -> Natalândia
#
# Índice 808: Amparo da Serra
#
# Índice 809: São Félix de Minas
#
# Índice 811: Areado
#
#     Colisão -> Caparaó
#
# Índice 814: Santa Rita de Caldas
#
# Índice 815: Senador Cortes
#
# Índice 816: Carmo da Mata
#
#     Colisão -> Wenceslau Braz
#     Colisão -> Umburatiba
#
#     Colisão -> Glaucilândia
#
# Índice 818: Cláudio
#
# Índice 820: Senador Amaral
#
# Índice 821: Materlândia
#
#     Colisão -> Monte Santo de Minas
#
# Índice 823: Entre Rios de Minas
#
# Índice 828: Indianópolis
#
#     Colisão -> Rubim
#
#     Colisão -> Presidente Juscelino
#
# Índice 830: Bocaiuva
#
# Índice 831: São Francisco de Sales
#
# Índice 832: Januária
#
# Índice 833: Lamim
#
# Índice 835: Jequeri
#
# Índice 836: Matipó
#
# Índice 840: Ituiutaba
#
#     Colisão -> Minas Novas
#
# Índice 841: Maravilhas
#
# Índice 842: Itacambira
#
# Índice 843: Botumirim
#
#     Colisão -> Jeceaba
#
# Índice 844: Campanha
#
#     Colisão -> Rochedo de Minas
#
# Índice 846: Belo Horizonte
#
# Índice 848: Itambé do Mato Dentro
#
#     Colisão -> Moema
#
# Índice 849: Chapada do Norte
#
# Índice 850: Moeda
#
# Índice 852: Funilândia
#
#     Colisão -> Ladainha
#
# Índice 856: Santa Rita de Minas
#
# Índice 857: Felisburgo
#
#     Colisão -> Igarapé
#
# Índice 858: Martinho Campos
#
#     Colisão -> Monte Belo
#
# Índice 0: Ressaquinha
#
# Índice 1: Jacutinga
#
#     Colisão -> Pingo-d'Água
#
# Índice 3: São Francisco
#
# Índice 4: Bom Sucesso
#
# Índice 6: Santa Cruz de Salinas
#
# Índice 8: Ervália
#
# Índice 9: Congonhas
#
#     Colisão -> Senhora dos Remédios
#
#     Colisão -> Monte Carmelo
#
# Índice 10: Jaboticatubas
#
#     Colisão -> Novo Cruzeiro
#
# Índice 11: Oliveira Fortes
#
# Índice 12: Alfenas
#
#     Colisão -> Prata
#
#     Colisão -> Patis
#
# Índice 13: Araporã
#
#     Colisão -> Passa Tempo
#
#     Colisão -> Carmo do Cajuru
#
# Índice 14: Santana do Deserto
#
# Índice 15: Chiador
#
#     Colisão -> Divino das Laranjeiras
#
# Índice 16: Francisco Sá
#
#     Colisão -> Iraí de Minas
#
# Índice 17: São Miguel do Anta
#
# Índice 18: Cristália
#
#     Colisão -> Maripá de Minas
#
#     Colisão -> Jampruca
#
#     Colisão -> Desterro de Entre Rios
#
# Índice 19: Guaraciaba
#
# Índice 21: Prudente de Morais
#
#     Colisão -> Silvianópolis
#
# Índice 24: Passa-Vinte
#
#     Colisão -> Tocantins
#
# Índice 25: Buritizeiro
#
#     Colisão -> Itacarambi
#
# Índice 27: Conceição da Barra de Minas
#
#     Colisão -> Diogo de Vasconcelos
#
# Índice 28: Araçuaí
#
# Índice 29: Rio Piracicaba
#
#     Colisão -> Senador Firmino
#
# Índice 30: Sacramento
#
# Índice 33: Bonfim
#
#     Colisão -> Ouro Fino
#
# Índice 34: Santa Juliana
#
# Índice 35: Soledade de Minas
#
# Índice 40: Ilicínea
#
#     Colisão -> São João da Lagoa
#
#     Colisão -> Inhapim
#
# Índice 41: Estrela do Indaiá
#
# Índice 42: Brasópolis
#
# Índice 43: Sete Lagoas
#
# Índice 44: Bandeira
#
#     Colisão -> Simonésia
#
# Índice 45: Caputira
#
# Índice 46: Coronel Murta
#
#     Colisão -> Extrema
#
# Índice 47: Brás Pires
#
# Índice 48: Santa Cruz do Escalvado
#
#     Colisão -> Santo Antônio do Aventureiro
#
# Índice 49: Ibertioga
#
# Índice 50: Resplendor
#
# Índice 51: Campestre
#
# Índice 52: Bambuí
#
# Índice 56: Coromandel
#
#     Colisão -> Jaíba
#
# Índice 57: Dona Eusébia
#
#     Colisão -> Guidoval
#
# Índice 58: Santa Bárbara do Tugúrio
#
# Índice 59: Acaiaca
#
#     Colisão -> Conceição das Pedras
#
# Índice 60: Antônio Carlos
#
# Índice 61: Cambuí
#
# Índice 62: Alvorada de Minas
#
#     Colisão -> Serranópolis de Minas
#
# Índice 63: Arceburgo
#
#     Colisão -> Goiabeira
#
# ...
#
# Índice 564: Coqueiral
#
# Índice 565: Mantena
#
# Índice 566: Guaxupé
#
# Índice 572: Monte Santo de Minas
#
# Índice 573: São Geraldo
#
# Índice 575: Guaraciama
#
# Índice 578: Congonhas do Norte
#
#     Colisão -> São Francisco do Glória
#
#     Colisão -> Cristiano Otoni
#
# Índice 581: Rio Pomba
#
# Índice 583: Januária
#
# Índice 584: Prudente de Morais
#
# Índice 586: São Thomé das Letras
#
# Índice 587: Matipó
#
# Índice 589: Francisco Dumont
#
#     Colisão -> Grão Mogol
#
# Índice 592: Coluna
#
#     Colisão -> Senador Firmino
#
# Índice 595: Santa Rita do Itueto
#
# Índice 603: Inhapim
#
# Índice 606: Itamarandiba
#
#     Colisão -> São João Nepomuceno
#
# Índice 607: Bandeira
#
# Índice 609: Monte Belo
#
# Índice 610: Brás Pires
#
#     Colisão -> Santana do Manhuaçu
#
#     Colisão -> Piranga
#
# Índice 612: Campos Gerais
#
# Índice 613: São Gonçalo do Sapucaí
#
# Índice 614: Nanuque
#
# Índice 617: Japonvar
#
#     Colisão -> São João do Manhuaçu
#
# Índice 618: Santa Bárbara
#
# Índice 619: Machado
#
# Índice 620: Águas Formosas
#
# Índice 621: São Joaquim de Bicas
#
# Índice 624: Araguari
#
# Índice 625: Raul Soares
#
# Índice 626: Itapagipe
#
# Índice 631: Coroaci
#
# Índice 632: Capitão Andrade
#
# Índice 634: São João da Mata
#
# Índice 636: Tarumirim
#
# Índice 641: Gonçalves
#
# Índice 642: Amparo da Serra
#
# Índice 648: Ninheira
#
# Índice 649: Oliveira Fortes
#
# Índice 650: Umburatiba
#
# Índice 654: Claraval
#
# Índice 655: Materlândia
#
# Índice 658: Mata Verde
#
# Índice 659: Carneirinho
#
# Índice 662: Juvenília
#
# Índice 663: Manhumirim
#
# Índice 665: Inconfidentes
#
# Índice 667: Vargem Alegre
#
# Índice 669: Nepomuceno
#
# Índice 674: São João Evangelista
#
# Índice 678: Desterro do Melo
#
# Índice 680: Cambuquira
#
# Índice 683: Alto Rio Doce
#
# Índice 684: São Geraldo do Baixio
#
# Índice 686: Uberaba
#
# Índice 687: Mendes Pimentel
#
# Índice 689: Piau
#
# Índice 690: Santa Rita de Minas
#
#     Colisão -> São Roque de Minas
#
# Índice 691: Santo Hipólito
#
# Índice 693: Felixlândia
#
# Índice 694: Coromandel
#
# Índice 697: Iguatama
#
# Índice 698: Antônio Carlos
#
# Índice 700: Alvorada de Minas
#
# Índice 704: Monte Formoso
#
# Índice 705: Jordânia
#
#     Colisão -> Sardoá
#
#     Colisão -> Santana do Paraíso
#
# Índice 708: Dores do Indaiá
#
# Índice 709: São José do Alegre
#
# Índice 710: Itanhandu
#
# Índice 711: Jequitinhonha
#
#     Colisão -> Porteirinha
#
# Índice 713: São Tomás de Aquino
#
# Índice 715: Manhuaçu
#
#     Colisão -> Marilac
#
# Índice 717: Nova Resende
#
# Índice 719: Abaeté
#
# Índice 720: Leme do Prado
#
#     Colisão -> Santana da Vargem
#
# Índice 721: Nova Belém
#
# Índice 722: Nova Lima
#
# Índice 723: Jaboticatubas
#
# Índice 725: Patis
#
# Índice 728: Divino das Laranjeiras
#
# Índice 729: Berilo
#
#     Colisão -> Montes Claros
#
# Índice 732: Taquaraçu de Minas
#
# Índice 734: Santo Antônio do Itambé
#
# Índice 735: São Gonçalo do Rio Abaixo
#
# Índice 738: Buritizeiro
#
# Índice 739: Albertina
#
# Índice 742: Nova Porteirinha
#
# Índice 744: Itanhomi
#
# Índice 753: São João da Lagoa
#
# Índice 756: Senhora de Oliveira
#
#     Colisão -> Sete Lagoas
#
# Índice 757: Simonésia
#
# Índice 758: Caputira
#
# Índice 761: Campanha
#
#     Colisão -> Santo Antônio do Aventureiro
#
#     Colisão -> Carmo do Paranaíba
#
# Índice 762: Ibertioga
#
# Índice 763: São José do Mantimento
#
# Índice 764: Lagoa da Prata
#
# Índice 765: Araxá
#
# Índice 771: Santa Bárbara do Tugúrio
#
# Índice 773: São Gonçalo do Abaeté
#
# Índice 775: Itatiaiuçu
#
#     Colisão -> Serranópolis de Minas
#
# Índice 776: Arceburgo
#
# Índice 779: Matias Barbosa
#
# Índice 781: Veríssimo
#
# Índice 783: Cabo Verde
#
# Índice 785: Careaçu
#
# Índice 786: Ipiaçu
#
#     Colisão -> Pedras de Maria da Cruz
#
# Índice 791: Senador José Bento
#
# Índice 792: Bom Sucesso
#
# Índice 800: Alfenas
#
# Índice 804: Iraí de Minas
#
# Índice 805: Taparuba
#
# Índice 806: Cristália
#
# Índice 808: Rodeiro
#
# Índice 813: Eugenópolis
#
# Índice 818: Sacramento
#
# Índice 819: Borda da Mata
#
# Índice 822: Santa Juliana
#
# Índice 828: Ipatinga
#
#     Colisão -> Medina
#
# Índice 830: Divisópolis
#
# Índice 831: Olaria
#
# Índice 833: Galileia
#
# Índice 835: Pouso Alegre
#
# Índice 843: Botumirim
#
#     Colisão -> Santa Bárbara do Monte Verde
#
# Índice 845: Ritápolis
#
# Índice 850: Luislândia
#
# Índice 851: Águas Vermelhas
#
#     Colisão -> Carmo da Cachoeira
#
# Índice 853: Fervedouro
#
# Índice 858: Martinho Campos
#
# Índice 859: Capinópolis
#
#     Colisão -> Pouso Alto
#
# Índice 863: Ressaquinha
#
# Índice 864: Jacutinga
#
#     Colisão -> Monjolos
#
# Índice 867: Monsenhor Paulo
#
# Índice 868: Durandé
#
# Índice 872: Senhora dos Remédios
#
# Índice 874: Pedro Leopoldo
#
# Índice 877: Santana do Deserto
#
# Índice 878: Chiador
#
# Índice 881: Claro dos Poções
#
#     Colisão -> Desterro de Entre Rios
#
# Índice 884: Itaipé
#
# Índice 885: Montezuma
#
# Índice 886: Simão Pereira
#
# Índice 887: Conceição da Aparecida
#
# Índice 888: Lavras
#
# Índice 890: Dom Viçoso
#
# Índice 892: Lagoa Santa
#
# Índice 893: Santo Antônio do Retiro
#
# Índice 896: Bonfim
#
# Índice 904: Estrela do Indaiá
#
# Índice 905: Lassance
#
# Índice 908: Virgínia
#
# Índice 910: Coimbra
#
#     Colisão -> São Gotardo
#
# Índice 913: Dom Joaquim
#
# Índice 918: Carvalhópolis
#
# Índice 920: Rio Espera
#
# Índice 921: Botelhos
#
# Índice 925: Nacip Raydan
#
# Índice 927: Alvinópolis
#
# Índice 929: Carmópolis de Minas
#
# Índice 932: Ibiracatu
#
# Índice 936: Arcos
#
# Índice 937: Caiana
#
#     Colisão -> Elói Mendes
#
# Índice 940: Montalvânia
#
# Índice 941: Carrancas
#
# Índice 945: Cachoeira de Pajeú
#
# Índice 952: Descoberto
#
# Índice 956: Bicas
#
# Índice 962: Padre Paraíso
#
# Índice 964: Capim Branco
#
# Índice 965: Pescador
#
#     Colisão -> Quartel Geral
#
# Índice 967: Juruaia
#
# Índice 968: Olhos-d'Água
#
# Índice 971: Piedade dos Gerais
#
# Índice 972: Conceição dos Ouros
#
# Índice 975: Onça de Pitangui
#
# Índice 976: São João do Oriente
#
# Índice 979: São João do Pacuí
#
# Índice 981: Mesquita
#
# Índice 983: Casa Grande
#
#     Colisão -> Santa Helena de Minas
#
# Índice 991: Pirapora
#
# Índice 996: Muzambinho
#
#     Colisão -> Salinas
#
# Índice 997: Conselheiro Pena
#
# Índice 1000: Capitólio
#
# Índice 1003: Santos Dumont
#
# Índice 1004: Mariana
#
# Índice 1006: Vazante
#
# Índice 1010: Carmo do Rio Claro
#
# Índice 1014: São Francisco de Paula
#
# Índice 1015: Alpercata
#
# Índice 1020: Turvolândia
#
# Índice 1022: Guimarânia
#
# Índice 1027: Miradouro
#
# Índice 1028: Josenópolis
#
# Índice 1030: João Pinheiro
#
# Índice 1032: Crisólita
#
#     Colisão -> Itabira
#
# Índice 1035: Poços de Caldas
#
#     Colisão -> Santa Rita de Jacutinga
#
# Índice 1036: Mathias Lobato
#
# Índice 1043: Nova Serrana
#
# Índice 1049: Volta Grande
#
# Índice 1050: Nova Módica
#
#     Colisão -> São Sebastião do Paraíso
#
# Índice 1052: Coração de Jesus
#
# Índice 1057: Cana Verde
#
# Índice 1061: Dores de Campos
#
#     Colisão -> Frei Gaspar
#
# Índice 1062: Ewbank da Câmara
#
# Índice 1063: Caldas
#
#     Colisão -> Manga
#
# Índice 1066: Cônego Marinho
#
# Índice 1071: Antônio Dias
#
# Índice 1072: Brasilândia de Minas
#
#     Colisão -> Rio Pardo de Minas
#
# Índice 1073: Luisburgo
#
# Índice 1074: Rio Acima
#
# Índice 1076: Itamonte
#
# Índice 1077: Jaguaraçu
#
#     Colisão -> Paineiras
#
# Índice 1078: Dores do Turvo
#
# Índice 1081: Malacacheta
#
#     Colisão -> São José da Varginha
#
# Índice 1083: Divisa Nova
#
# Índice 1084: Cássia
#
# Índice 1091: Verdelândia
#
# Índice 1092: Inimutaba
#
# Índice 1098: Couto de Magalhães de Minas
#
#     Colisão -> Jacinto
#
# Índice 1107: Vargem Bonita
#
# Índice 1110: Carangola
#
#     Colisão -> Ibituruna
#
# Índice 1111: Piedade de Ponte Nova
#
# Índice 1115: Matias Cardoso
#
# Índice 1116: Tupaciguara
#
# Índice 1117: Comercinho
#
# Índice 1121: Fortaleza de Minas
#
# Índice 1122: Bias Fortes
#
# Índice 1131: Divisa Alegre
#
# Índice 1135: Rio Doce
#
# Índice 1138: Itaú de Minas
#
# Índice 1139: Santa Vitória
#
# Índice 1142: Planura
#
# Índice 1143: Alto Jequitibá
#
#     Colisão -> Araújos
#
# Índice 1146: Iapu
#
# Índice 1149: Buritis
#
# Índice 1160: Mato Verde
#
# Índice 1164: Angelândia
#
# Índice 1166: Palmópolis
#
# Índice 1167: Pequeri
#
# Índice 1174: Machacalis
#
# Índice 1175: São Gonçalo do Rio Preto
#
# Índice 1178: Belmiro Braga
#
#     Colisão -> Reduto
#
# Índice 1182: Crucilândia
#
#     Colisão -> Gonzaga
#
# Índice 1187: José Gonçalves de Minas
#
# Índice 1188: Entre Folhas
#
# Índice 1189: Patrocínio do Muriaé
#
# Índice 1190: Várzea da Palma
#
# Índice 1195: Chalé
#
# Índice 1199: Itamarati de Minas
#
#     Colisão -> Prados
#
# Índice 1201: Alpinópolis
#
#     Colisão -> Pavão
#
#     Colisão -> Caraí
#
# Índice 1202: Mamonas
#
# Índice 1206: Luminárias
#
# Índice 1207: Bom Jesus da Penha
#
# Índice 1208: Carvalhos
#
# Índice 1211: São José da Lapa
#
# Índice 1212: Cordisburgo
#
#     Colisão -> Formoso
#
# Índice 1215: São João Batista do Glória
#
# Índice 1221: Alterosa
#
# Índice 1225: Cruzília
#
# Índice 1226: Campo Florido
#
#     Colisão -> Fernandes Tourinho
#
# Índice 1229: Pedra do Indaiá
#
# Índice 1232: Cajuri
#
# Índice 1233: Aimorés
#
# Índice 1234: Paiva
#
# Índice 1236: Rio Paranaíba
#
# Índice 1242: Periquito
#
# Índice 1248: Campo Belo
#
# Índice 1249: Antônio Prado de Minas
#
#     Colisão -> Seritinga
#
# Índice 1253: Carmo de Minas
#
#     Colisão -> Córrego Fundo
#
# Índice 1256: Mar de Espanha
#
# Índice 1264: Rio Manso
#
# Índice 1266: Ponto dos Volantes
#
#     Colisão -> Serra do Salitre
#
#     Colisão -> São Gonçalo do Pará
#
# Índice 1267: Pequi
#
# Índice 1268: Ubá
#
# Índice 1269: Martins Soares
#
# Índice 1273: Limeira do Oeste
#
# Índice 1277: Santa Luzia
#
# Índice 1278: Alfredo Vasconcelos
#
#     Colisão -> Canaã
#
# Índice 1279: Bom Jesus do Galho
#
# Índice 1282: Rio Casca
#
# Índice 1283: Guarará
#
# Índice 1284: Barra Longa
#
#     Colisão -> Pará de Minas
#
# Índice 1289: Diamantina
#
# Índice 1290: Conceição de Ipanema
#
# Índice 1292: Pintópolis
#
# Índice 1297: Brumadinho
#
# Índice 1301: Carbonita
#
# Índice 1302: Capitão Enéas
#
# Índice 1304: Pedralva
#
# Índice 1306: Andradas
#
# Índice 1308: Conceição do Mato Dentro
#
# Índice 1309: Frei Inocêncio
#
# Índice 1311: Papagaios
#
# Índice 1313: Frutal
#
# Índice 1319: Santo Antônio do Monte
#
#     Colisão -> São João do Manteninha
#
# Índice 1320: Muriaé
#
# Índice 1325: Poté
#
# Índice 1328: Bom Despacho
#
# Índice 1331: Divinolândia de Minas
#
# Índice 1333: Passos
#
# Índice 1336: Rubelita
#
# Índice 1338: Curral de Dentro
#
#     Colisão -> Pompéu
#
# Índice 1340: Lontra
#
# Índice 1341: Santana do Garambéu
#
# Índice 1342: Campos Altos
#
#     Colisão -> Teixeiras
#
# Índice 1343: Carmo da Mata
#
# Índice 1344: Ibiaí
#
# Índice 1347: Resende Costa
#
#     Colisão -> Senador Amaral
#
# Índice 1348: Araçaí
#
#     Colisão -> Virgem da Lapa
#
# Índice 1351: Água Comprida
#
# Índice 1352: Bom Jardim de Minas
#
# Índice 1355: Itaverava
#
# Índice 1357: Bocaiuva
#
#     Colisão -> Recreio
#
#     Colisão -> Matutina
#
# Índice 1358: São Pedro do Suaçuí
#
# Índice 1360: Camanducaia
#
# Índice 1361: Timóteo
#
# Índice 1363: Betim
#
# Índice 1368: Joaíma
#
# Índice 1376: Chapada do Norte
#
# Índice 1384: Felisburgo
#
# Índice 1386: Senador Modestino Gonçalves
#
# Índice 1387: Curvelo
#
# Índice 1389: Água Boa
#
# Índice 1393: Poço Fundo
#
# Índice 1394: Divino
#
# Índice 1395: Sapucaí-Mirim
#
# Índice 1396: Lajinha
#
# Índice 1397: Miravânia
#
#     Colisão -> Virgolândia
#
# Índice 1398: Cataguases
#
# Índice 1401: Riacho dos Machados
#
# Índice 1404: Bertópolis
#
# Índice 1406: Pedra Azul
#
# Índice 1412: Morro da Garça
#
# Índice 1413: Baependi
#
# Índice 1416: Carandaí
#
# Índice 1419: São Félix de Minas
#
# Índice 1420: São Tiago
#
# Índice 1424: Santa Rita de Caldas
#
# Índice 1425: Pratinha
#
# Índice 1428: Santa Rita do Sapucaí
#
# Índice 1432: Camacho
#
# Índice 1439: Carmo do Cajuru
#
#     Colisão -> Lagoa Dourada
#
# Índice 1443: Ubaporanga
#
# Índice 1445: Jequeri
#
# Índice 1447: Porto Firme
#
# Índice 1452: Coronel Pacheco
#
#     Colisão -> Itacambira
#
# Índice 1453: Pedra Dourada
#
# Índice 1454: Rochedo de Minas
#
# Índice 1457: Catuji
#
# Índice 1462: Ladainha
#
# Índice 1467: Igarapé
#
# Índice 1468: Janaúba
#
# Índice 1469: Arinos
#
#     Colisão -> Monte Sião
#
# Índice 1472: Extrema
#
# Índice 1473: Presidente Kubitschek
#
# Índice 1477: São Romão
#
# Índice 1479: Pocrane
#
# Índice 1482: Córrego do Bom Jesus
#
#     Colisão -> São João das Missões
#
# Índice 1483: Dona Eusébia
#
# Índice 1493: Passa-Quatro
#
# Índice 1501: Cordislândia
#
# Índice 1504: Carlos Chagas
#
# Índice 1507: Serro
#
# Índice 1508: Pedra Bonita
#
# Índice 1509: Glaucilândia
#
#     Colisão -> Wenceslau Braz
# Índice 1510: Monte Carmelo
#
# Índice 1511: Cláudio
#
#     Colisão -> Novo Cruzeiro
#
# Índice 1514: Bela Vista de Minas
#
# Índice 1517: Francisco Sá
#
# Índice 1518: São Miguel do Anta
#
# Índice 1520: Guaraciaba
#
# Índice 1522: Silvianópolis
#
#     Colisão -> Varginha
#
# Índice 1523: São Vicente de Minas
#
# Índice 1526: Pimenta
#
#     Colisão -> Sabará
#
# Índice 1528: Diogo de Vasconcelos
#
# Índice 1533: Carmésia
#
# Índice 1534: Maravilhas
#
# Índice 1541: Itambé do Mato Dentro
#
# Índice 1549: Santa Cruz do Escalvado
#
# Índice 1557: Urucuia
#
# Índice 1558: Caranaíba
#
#     Colisão -> São João del-Rei
#
# Índice 1562: Cambuí
#
# Índice 1564: Cascalho Rico
#
#     Colisão -> Faria Lemos
#
#     Colisão -> Espinosa
#
# Índice 1565: Conquista
#
# Índice 1566: Aricanduva
#
# Índice 1568: Buenópolis
#
# Índice 1573: Ipaba
#
# Índice 1574: Dom Silvério
#
# Índice 1576: Taiobeiras
#
# Índice 1577: Perdizes
#
# Índice 1579: Augusto de Lima
#
# Índice 1580: Pedra do Anta
#
# Índice 1582: Itaguara
#
#     Colisão -> Santa Cruz de Salinas
#
#     Colisão -> Natalândia
#
# Índice 1589: Coronel Fabriciano
#
# Índice 1591: Senador Cortes
#
#     Colisão -> Vargem Grande do Rio Pardo
#
# Índice 1596: Nova Ponte
#
# Índice 1597: Doresópolis
#
# Índice 1604: Contagem
#
#     Colisão -> Rubim
#
# Índice 1605: Rio Piracicaba
#
# Índice 1607: Mutum
#
# Índice 1609: Lamim
#
# Índice 1611: Soledade de Minas
#
# Índice 1613: Japaraíba
#
# Índice 1616: Minas Novas
#
# Índice 1618: Ribeirão Vermelho
#
# Índice 1619: Jeceaba
#
# Índice 1631: Presidente Olegário
#
#     Colisão -> Serra Azul de Minas
#
# Índice 1633: São Domingos do Prata
#
# Índice 1635: Acaiaca
#
# Índice 1644: Lima Duarte
#
# Índice 1648: São José do Goiabal
#
# Índice 1649: Pitangui
#
#     Colisão -> São José do Divino
#
# Índice 1651: Ibiá
#
# Índice 1652: Pingo-d'Água
#
# Índice 1653: Esmeraldas
#
# Índice 1657: Guapé
#
#     Colisão -> Itambacuri
#
# Índice 1659: Ervália
#
# Índice 1661: São João da Ponte
#
# Índice 1663: Prata
#
# Índice 1668: Ponto Chique
#
#     Colisão -> São João do Paraíso
#
# Índice 1671: Silveirânia
#
# Índice 1674: Abre-Campo
#
# Índice 1678: Piedade do Rio Grande
#
#     Colisão -> São José do Jacuri
#
# Índice 1679: Tombos
#
# Índice 1683: Argirita
#
# Índice 1685: Coronel Xavier Chaves
#
# Índice 1687: Formiga
#
#     Colisão -> Indianópolis
#
# Índice 1690: São Francisco de Sales
#
# Índice 1693: São Bento Abade
#
# Índice 1694: Morada Nova de Minas
#
# Índice 1702: Campestre
#
# Índice 1707: Jaíba
#
#     Colisão -> Moema
#
# Índice 1709: Moeda
#
# Índice 1711: Pirapetinga
#
# Índice 1714: Riachinho
#
# Índice 1715: Sarzedo
#
#     Colisão -> Serrania
#
# Índice 1716: Varjão de Minas
#
# Índice 1718: Florestal
#
# Índice 1720: Itaúna
#
# Índice 1723: Sobrália
#
# Índice 1725: Presidente Bernardes
#
# Índice 1728: Córrego Novo
#
#     Colisão -> Varzelândia
#
# Índice 1735: Viçosa
#
# Índice 1736: Paracatu
#
# Índice 1739: Araporã
#
# Índice 1740: Canápolis
#
# Índice 1741: Governador Valadares
#
# Índice 1742: Jacuí
#
# Índice 1748: Santa Cruz de Minas
#
# Índice 1751: Guanhães
#
# Índice 1752: Paraguaçu
#
# Índice 1753: Cipotânea
#
# Índice 1755: Espírito Santo do Dourado
#
#     Colisão -> Santo Antônio do Rio Abaixo
#
# Índice 1756: Ferros
#
# Índice 1759: Estrela Dalva
#
#     Colisão -> Ouro Fino
#
# Índice 1768: Brasópolis
#
#     Colisão -> Tiradentes
#
# Índice 1771: Rosário da Limeira
#
# Índice 1773: Candeias
#
# Índice 1774: Ingaí
#
# Índice 1776: Belo Vale
#
# Índice 1780: Campanário
#
#     Colisão -> Itapecerica
#
# Índice 1783: Conceição do Rio Verde
#
#     Colisão -> Santa Efigênia de Minas
#
# Índice 1785: Conceição das Pedras
#
# Índice 1788: Santana de Pirapama
#
# Índice 1793: Conceição do Pará
#
# Índice 1794: São Sebastião da Vargem Alegre
#
# Índice 1795: Imbé de Minas
#
# Índice 1797: Cedro do Abaeté
#
# Índice 1798: Pedrinópolis
#
# Índice 1800: Minduri
#     tamanho_tabela  colisoes  maior_lista_colisao  tempo_execucao
# 0              857       298                    5        0.003988
# 1              859       306                    5        0.003990
# 2              863       305                    4        0.002992
# 3              877       315                    5        0.002992
# 4              907       304                    3        0.005985
# 5              953       295                    5        0.002991
# 6             1709       184                    4        0.002992
# 7             1741       180                    4        0.002992
# 8             1759       177                    3        0.001994
# 9             1789       169                    3        0.002992
# 10            1801       144                    3        0.002992

# %%
class no:
    def __init__(self,chave):
        self.chave=chave
        self.proximo = None
        self.anterior = None
        
class ListaEncadeada:
    def __init__(self):
        self.inicio = None
        
    def inserir(self,valor):
        novo = no(valor)
        if self.inicio == None:
            self.inicio = novo
            novo.anterior = self.inicio
        else:
            novo.proximo = self.inicio  
            self.inicio.anterior = novo  
            self.inicio = novo  

# Calasse Tabela Hash
class TabelaHash:
    
    def __init__(self): # Metodo que instancia a classe
        self.indice = None
        self.valor = None
        self.tamanhoLista = 0
        self.proximo = ListaEncadeada()
    
    def criarTabela(self,tamanho):
        tabela = []
        for i in range(tamanho):
            tabela.append(TabelaHash())
        return tabela
    
    def inicializaTabela(self,tamanho):
        tabela = self.criarTabela(tamanho)  
        for i in range(tamanho):
            tabela[i].indice = i
            tabela[i].valor = None
            self.tamanhoLista = 0
            tabela[i].proximo = ListaEncadeada()
        return tabela
    # Continuar implementação
    def inserirTabela(self,tabela,elemento,tamanho):
        modIndice = int(''.join(str(ord(c)) for c in elemento)) % tamanho
        if tabela[modIndice].valor == None:
            tabela[modIndice].valor = elemento
        else:
            tabela[modIndice].proximo.inserir(elemento)
            tabela[modIndice].tamanhoLista+=1

# %%
def testarEficiencia(tamanhos_tabelas,lista_cidades):
    resultados = []
    colisoes = 0
    maior = 0
    for tam in tamanhos_tabelas:
        tabela_hash = TabelaHash()
        tabela = tabela_hash.inicializaTabela(tam)
        inicio = time()
        for cidade in lista_cidades:
            tabela_hash.inserirTabela(tabela,cidade,tam)
        fim = time()
        for i in range(tam):
            if tabela[i].valor is not None:
                print(f"Índice {i}: {tabela[i].valor}")
                no_atual = tabela[i].proximo.inicio
                while no_atual:
                    print(f"    Colisão -> {no_atual.chave}")
                    no_atual = no_atual.proximo
                    colisoes += 1
        for i in range(tam):
            if tabela[i].tamanhoLista > maior:
                maior = tabela[i].tamanhoLista
        resultados.append({
            "tamanho_tabela": tam,
            "colisoes": colisoes,
            "maior_lista_colisao": maior,
            "tempo_execucao": fim - inicio
        })
        colisoes = 0
        maior = 0
    return resultados
with open(r'C:\Users\rafam\Desktop\ED2\ED2\cidades.txt', 'r') as arquivo:

    lista_cidades = arquivo.readlines()
tamanhos_tabelas = [857,859,863,877,907,953,1709,1741,1759,1789,1801]
resultado = testarEficiencia(tamanhos_tabelas,lista_cidades)
resultado_df2 = pd.DataFrame(resultado)

resultado_df2
# Out:
# Índice 0: Buenópolis
#
#     Colisão -> Santos Dumont
#
#     Colisão -> Engenheiro Navarro
#
#     Colisão -> Carvalhópolis
#
# Índice 1: Franciscópolis
#
#     Colisão -> Porto Firme
#
#     Colisão -> Guaraciaba
#
# Índice 2: Senador Modestino Gonçalves
#
# Índice 4: Carmo do Paranaíba
#
# Índice 5: Cláudio
#
# Índice 7: Catas Altas
#
#     Colisão -> Santana de Pirapama
#
# Índice 8: São Sebastião do Rio Verde
#
# Índice 9: São Félix de Minas
#
#     Colisão -> Virgem da Lapa
#
# Índice 10: Santa Bárbara do Leste
#
# Índice 12: Oliveira Fortes
#
#     Colisão -> Varjão de Minas
#
# Índice 13: Formoso
#
#     Colisão -> Manga
#
# Índice 14: Cabo Verde
#
# Índice 16: Brasília de Minas
#
#     Colisão -> Juramento
#
# Índice 17: Caldas
#
# Índice 18: São Sebastião do Oeste
#
#     Colisão -> Tumiritinga
#
# Índice 19: Teixeiras
#
# Índice 20: Campestre
#
#     Colisão -> Pescador
#
# Índice 21: Divinópolis
#
# Índice 22: Cordislândia
#
#     Colisão -> Perdizes
#
# Índice 23: Córrego do Bom Jesus
#
#     Colisão -> Virgolândia
#
# Índice 24: Nepomuceno
#
# Índice 25: Matipó
#
# Índice 26: Coronel Xavier Chaves
#
#     Colisão -> Três Corações
#
#     Colisão -> São João del-Rei
#
# Índice 27: Bonfim
#
# Índice 28: Felixlândia
#
# Índice 30: Conceição do Pará
#
#     Colisão -> Ibituruna
#
# Índice 32: Tapira
#
# Índice 33: Barroso
#
#     Colisão -> Itamogi
#
# Índice 36: Miraí
#
#     Colisão -> Santa Maria de Itabira
#
#     Colisão -> Paracatu
#
# Índice 37: Guapé
#
# Índice 39: Salinas
#
# Índice 40: Crucilândia
#
# Índice 42: Capitão Andrade
#
# Índice 43: Passa-Vinte
#
# Índice 45: Florestal
#
# Índice 48: Patis
#
# Índice 50: Itaipé
#
# Índice 51: Oratórios
#
# Índice 53: Santana do Garambéu
#
# Índice 54: Cedro do Abaeté
#
#     Colisão -> São Joaquim de Bicas
#
# Índice 55: Santa Rita do Itueto
#
#     Colisão -> Turmalina
#
#     Colisão -> São Francisco de Paula
#
# Índice 56: Marmelópolis
#
# Índice 58: Passabém
#
#     Colisão -> Ritápolis
#
# Índice 60: Desterro de Entre Rios
#
# Índice 61: Dores do Turvo
#
# Índice 62: Bom Sucesso
#
#     Colisão -> Serra Azul de Minas
#
# Índice 63: São João das Missões
#
# Índice 65: Arcos
#
# Índice 66: Contagem
#
#     Colisão -> Tarumirim
#
#     Colisão -> São João da Lagoa
#
# Índice 68: Água Boa
#
# Índice 70: Cajuri
#
# Índice 72: Francisco Dumont
#
# Índice 73: Cristiano Otoni
#
# Índice 74: Cachoeira de Minas
#
# Índice 75: Conceição do Mato Dentro
#
# Índice 77: Carneirinho
#
#     Colisão -> São Gotardo
#
# Índice 79: Virginópolis
#
# Índice 82: Augusto de Lima
#
#     Colisão -> Senador Firmino
#
# Índice 83: Pouso Alto
#
# Índice 84: Diamantina
#
# Índice 86: Bocaina de Minas
#
# Índice 87: Coimbra
#
# Índice 89: Paraisópolis
#
# Índice 90: Paula Cândido
#
# Índice 91: Antônio Carlos
#
# Índice 95: Indaiabira
#
# Índice 96: Arinos
#
# Índice 97: Funilândia
#
# Índice 98: Pedro Leopoldo
#
# Índice 99: Paulistas
#
# Índice 100: Catuji
#
#     Colisão -> Coromandel
#
# Índice 101: Faria Lemos
#
# Índice 102: Biquinhas
#
#     Colisão -> Itaverava
#
# Índice 104: Araújos
#
#     Colisão -> Delfinópolis
#
# Índice 107: Elói Mendes
#
# Índice 109: Divinésia
#
#     Colisão -> Dom Viçoso
#
# Índice 110: Igaratinga
#
#     Colisão -> Riachinho
#
#     Colisão -> Reduto
#
#     Colisão -> Pocrane
#
# Índice 111: Arceburgo
#
#     Colisão -> Jesuânia
#
#     Colisão -> Coroaci
#
# Índice 112: Lagoa Grande
#
# Índice 113: Águas Formosas
#
#     Colisão -> Leme do Prado
#
# Índice 114: Córrego Fundo
#
# Índice 118: São João da Ponte
#
#     Colisão -> Tombos
#
# Índice 119: Janaúba
#
# Índice 120: Lagoa Formosa
#
#     Colisão -> São João do Manhuaçu
#
# Índice 121: Japonvar
#
# Índice 124: Corinto
#
#     Colisão -> Tocos do Moji
#
#     Colisão -> Ervália
#
#     Colisão -> Coronel Fabriciano
#
# Índice 128: Alpinópolis
#
#     Colisão -> Delta
#
# Índice 129: Amparo da Serra
#
#     Colisão -> Nova Serrana
#
#     Colisão -> Lima Duarte
#
#     Colisão -> Arantina
#
# Índice 132: Mar de Espanha
#
#     Colisão -> Santo Antônio do Itambé
#
# Índice 133: Berilo
#
#     Colisão -> Malacacheta
#
#     Colisão -> Divino das Laranjeiras
#
# Índice 134: Paraguaçu
#
#     Colisão -> Santo Antônio do Monte
#
# Índice 135: Itambacuri
#
# Índice 136: Carbonita
#
#     Colisão -> São João do Manteninha
#
#     Colisão -> Casa Grande
#
# Índice 137: Conceição dos Ouros
#
# Índice 140: Poços de Caldas
#
# Índice 141: Açucena
#
#     Colisão -> Bicas
#
# Índice 144: Alagoa
#
# Índice 145: Abadia dos Dourados
#
# Índice 148: Campo Florido
#
# Índice 149: Espera Feliz
#
#     Colisão -> Senador Amaral
#
#     Colisão -> Montalvânia
#
# Índice 152: Umburatiba
#
# Índice 154: Estrela Dalva
#
#     Colisão -> Santana do Deserto
#
# Índice 155: Congonhal
#
#     Colisão -> Serranópolis de Minas
#
#     Colisão -> Fervedouro
#
# Índice 156: Ouro Fino
#
# Índice 163: Araporã
#
#     Colisão -> Pedra Azul
#
#     Colisão -> Mendes Pimentel
#
# Índice 164: Taquaraçu de Minas
#
#     Colisão -> Toledo
#
# Índice 165: Senhora do Porto
#
# Índice 166: Vieiras
#
# Índice 167: Belo Oriente
#
# Índice 170: Canápolis
#
# Índice 171: Eugenópolis
#
#     Colisão -> Santo Antônio do Amparo
#
#     Colisão -> Nova União
#
# Índice 172: Jordânia
#
#     Colisão -> Serranos
#
# Índice 173: Bom Despacho
#
#     Colisão -> Caparaó
#
# Índice 174: Wenceslau Braz
# Índice 175: Vespasiano
#
# Índice 176: Sardoá
#
# Índice 178: Cruzeiro da Fortaleza
#
#     Colisão -> Taiobeiras
#
# Índice 179: São José da Safira
#
# Índice 180: Alvarenga
#
# Índice 182: Rubelita
#
# Índice 183: Luz
#
#     Colisão -> Santana da Vargem
#
#     Colisão -> Rio Piracicaba
#
#     Colisão -> Pedra do Anta
#
# Índice 184: Claro dos Poções
#
#     Colisão -> Coronel Murta
#
# Índice 185: Santa Rita de Ibitipoca
#
# Índice 186: Delfim Moreira
#
# Índice 187: Comendador Gomes
#
#     Colisão -> Lavras
#
#     Colisão -> Grupiara
#
# Índice 188: Dom Silvério
#
#     Colisão -> José Raydan
#
# Índice 190: Coqueiral
#
# Índice 193: Arapuá
#
#     Colisão -> Recreio
#
# Índice 196: Fortuna de Minas
#
#     Colisão -> Pains
#
# Índice 198: Liberdade
#
#     Colisão -> Sem-Peixe
#
# Índice 200: Almenara
#
# Índice 201: Gonzaga
#
#     Colisão -> Morro da Garça
#
# Índice 202: Alpercata
#
#     Colisão -> São João do Pacuí
#
# Índice 203: Piau
#
#     Colisão -> Piedade dos Gerais
#
# Índice 204: Conselheiro Pena
#
# Índice 205: Carmópolis de Minas
#
# Índice 206: Frei Gaspar
#
# Índice 207: Rio Pardo de Minas
#
# Índice 209: Cachoeira Dourada
#
#     Colisão -> Caraí
#
# Índice 210: Boa Esperança
#
# Índice 211: Sobrália
#
# Índice 213: Araçaí
#
# Índice 215: Jacuí
#
# Índice 216: Candeias
#
#     Colisão -> Monsenhor Paulo
#
# Índice 217: Engenheiro Caldas
#
#     Colisão -> Juvenília
#
# Índice 218: São Geraldo do Baixio
#
# Índice 219: Campo do Meio
#
# Índice 222: Resplendor
#
#     Colisão -> Turvolândia
#
# Índice 224: Monjolos
#
# Índice 227: Capinópolis
#
#     Colisão -> Monte Azul
#
#     Colisão -> Jeceaba
#
#     Colisão -> Córrego Danta
#
# Índice 228: Cambuquira
#
# Índice 229: Comercinho
#
# Índice 230: São Domingos das Dores
#
# Índice 236: Rio Manso
#
# Índice 238: Andrelândia
#
#     Colisão -> Cataguases
#
# Índice 241: Dom Joaquim
#
# Índice 244: Conceição do Rio Verde
#
# Índice 246: Ibiá
#
#     Colisão -> Santo Antônio do Grama
#
# Índice 247: Camanducaia
#
#     Colisão -> Natalândia
#
# Índice 248: Santa Helena de Minas
#
# Índice 249: Santa Bárbara do Monte Verde
#
# Índice 250: Careaçu
#
#     Colisão -> Congonhas do Norte
#
#     Colisão -> Conceição das Alagoas
#
# Índice 251: Crisólita
#
#     Colisão -> Luisburgo
#
# Índice 252: Cruzília
#
#     Colisão -> Martinho Campos
#
# Índice 253: Rochedo de Minas
#
# Índice 254: Catas Altas da Noruega
#
#     Colisão -> Mesquita
#
# Índice 255: Confins
#
#     Colisão -> São Francisco
#
# Índice 256: Grão Mogol
#
#     Colisão -> Iraí de Minas
#
# Índice 260: Joaquim Felício
#
# Índice 268: Resende Costa
#
# Índice 269: Alto Caparaó
#
# Índice 270: Belo Vale
#
# Índice 271: Cristália
#
#     Colisão -> Pirapora
#
#     Colisão -> Olhos-d'Água
#
# Índice 272: Antônio Dias
#
# Índice 273: Guanhães
#
#     Colisão -> Ponto dos Volantes
#
#     Colisão -> Mariana
#
#     Colisão -> Juiz de Fora
#
#     Colisão -> Itanhandu
#
# Índice 274: Caxambu
#
#     Colisão -> Orizânia
#
#     Colisão -> Ibiaí
#
# Índice 275: Areado
#
# Índice 277: São Gonçalo do Rio Abaixo
#
# Índice 278: São Gonçalo do Abaeté
#
# Índice 279: São Gonçalo do Pará
#
# Índice 281: Além Paraíba
#
#     Colisão -> Santo Antônio do Aventureiro
#
# Índice 283: Dom Bosco
#
# Índice 286: Martins Soares
#
# Índice 287: São Lourenço
#
# Índice 288: Braúnas
#
#     Colisão -> Jacinto
#
# Índice 289: Caratinga
#
#     Colisão -> Tapiraí
#
#     Colisão -> Governador Valadares
#
# Índice 290: Itaú de Minas
#
#     Colisão -> Romaria
#
# Índice 291: Cascalho Rico
#
#     Colisão -> Ubaí
#
# Índice 292: Curral de Dentro
#
# Índice 294: Vargem Grande do Rio Pardo
#
# Índice 295: Piranga
#
# Índice 296: Caiana
#
#     Colisão -> Senhora de Oliveira
#
#     Colisão -> Patrocínio do Muriaé
#
#     Colisão -> Machacalis
#
# Índice 297: Durandé
#
#     Colisão -> Sapucaí-Mirim
#
# Índice 298: Carmésia
#
# Índice 300: Serro
#
# Índice 301: São João da Mata
#
# Índice 302: José Gonçalves de Minas
#
#     Colisão -> Nova Era
#
# Índice 307: Gonçalves
#
# Índice 309: Itatiaiuçu
#
# Índice 310: Indianópolis
#
# Índice 313: Ribeirão das Neves
#
#     Colisão -> São Francisco do Glória
#
# Índice 316: Salto da Divisa
#
# Índice 317: Ninheira
#
#     Colisão -> Santa Rita de Jacutinga
#
# Índice 318: Bom Repouso
#
#     Colisão -> São José do Mantimento
#
#     Colisão -> Ribeirão Vermelho
#
#     Colisão -> Inhapim
#
# Índice 319: Desterro do Melo
#
# Índice 320: Alvinópolis
#
#     Colisão -> Iapu
#
# Índice 321: Nanuque
#
# Índice 322: Couto de Magalhães de Minas
#
#     Colisão -> Palma
#
# Índice 324: Bandeira
#
# Índice 325: Uruana de Minas
#
# Índice 326: Bertópolis
#
#     Colisão -> Ibiracatu
#
# Índice 327: Alto Jequitibá
#
# Índice 331: Glaucilândia
#
#     Colisão -> Mato Verde
#
# Índice 332: Pintópolis
#
# Índice 335: Cônego Marinho
#
#     Colisão -> Monte Belo
#
# Índice 336: Itueta
#
# Índice 337: Cana Verde
#
#     Colisão -> São Tomás de Aquino
#
#     Colisão -> Josenópolis
#
#     Colisão -> Fruta de Leite
#
# Índice 338: Novorizonte
#
# Índice 339: Alvorada de Minas
#
#     Colisão -> Serrania
#
# Índice 342: Setubinha
#
# Índice 345: Lagoa da Prata
#
#     Colisão -> Matutina
#
# Índice 346: Jequitibá
#
# Índice 348: Araguari
#
#     Colisão -> Senador José Bento
#
#     Colisão -> Jequitaí
#
#     Colisão -> Ipatinga
#
# Índice 353: São José do Divino
#
# Índice 354: Cipotânea
#
#     Colisão -> Conceição de Ipanema
#
# Índice 355: Aguanil
#
# Índice 358: Aimorés
#
#     Colisão -> Pequi
#
# Índice 359: Nova Módica
#
# Índice 361: Serra dos Aimorés
#
# Índice 363: Bueno Brandão
#
#     Colisão -> Santa Juliana
#
# Índice 364: Matias Barbosa
#
# Índice 366: Fernandes Tourinho
#
#     Colisão -> Presidente Bernardes
#
# Índice 367: Itapeva
#
# Índice 370: Dionísio
#
#     Colisão -> Santa Rita do Sapucaí
#
# Índice 371: João Pinheiro
#
# Índice 372: Goiabeira
#
#     Colisão -> Presidente Juscelino
#
#     Colisão -> Juruaia
#
# Índice 374: Aricanduva
#
#     Colisão -> São José da Lapa
#
#     Colisão -> Brás Pires
#
# Índice 375: Januária
#
#     Colisão -> Padre Carvalho
#
# Índice 376: Guiricema
#
# Índice 377: Imbé de Minas
#
# Índice 378: Tocantins
#
# Índice 379: Mathias Lobato
#
# Índice 380: Formiga
#
#     Colisão -> Piedade de Ponte Nova
#
# Índice 386: Jequitinhonha
#
#     Colisão -> Vargem Bonita
#
# Índice 387: Capelinha
#
#     Colisão -> Jacutinga
#
# Índice 388: Botumirim
#
# Índice 389: Santa Cruz do Escalvado
#
# Índice 390: Albertina
#
#     Colisão -> Gurinhatã
#
# Índice 391: Papagaios
#
# Índice 392: São Pedro da União
#
# Índice 394: Santo Antônio do Rio Abaixo
#
# Índice 395: Muriaé
#
# Índice 399: Capim Branco
#
#     Colisão -> Rodeiro
#
# Índice 405: Cristais
#
#     Colisão -> Unaí
#
# Índice 406: Prata
#
# Índice 407: Ilicínea
#
#     Colisão -> Itumirim
#
# Índice 408: Cambuí
#
#     Colisão -> Itabira
#
#     Colisão -> Divisa Alegre
#
# Índice 409: Argirita
#
#     Colisão -> Ubá
#
#     Colisão -> Tiradentes
#
#     Colisão -> Pratinha
#
#     Colisão -> Ponto Chique
#
#     Colisão -> Marliéria
#
#     Colisão -> Ataléia
#
# Índice 410: Matias Cardoso
#
# Índice 411: Passa Tempo
#
#     Colisão -> Verdelândia
#
# Índice 412: Santo Antônio do Jacinto
#
# Índice 415: Queluzito
#
# Índice 416: Igarapé
#
# Índice 417: Monte Sião
#
# Índice 419: Francisco Sá
#
# Índice 420: Campina Verde
#
#     Colisão -> Novo Oriente de Minas
#
# Índice 422: Chiador
#
#     Colisão -> São Sebastião da Bela Vista
#
# Índice 423: Inconfidentes
#
#     Colisão -> Quartel Geral
#
#     Colisão -> Pompéu
#
# Índice 425: Mata Verde
#
# Índice 426: Pará de Minas
#
# Índice 427: Bonfinópolis de Minas
#
#     Colisão -> Piedade do Rio Grande
#
#     Colisão -> Morada Nova de Minas
#
# Índice 430: Muzambinho
#
# Índice 431: Belmiro Braga
#
#     Colisão -> Santo Hipólito
#
# Índice 432: Gouveia
#
# Índice 433: Betim
#
#     Colisão -> Lagoa dos Patos
#
# Índice 434: Guarará
#
# Índice 435: Sarzedo
#
# Índice 436: Viçosa
#
# Índice 438: Chácara
#
# Índice 439: Brasópolis
#
#     Colisão -> Maravilhas
#
#     Colisão -> João Monlevade
#
#     Colisão -> Cuparaque
#
# Índice 440: Espírito Santo do Dourado
#
# Índice 441: Conceição da Barra de Minas
#
# Índice 442: Fronteira dos Vales
#
#     Colisão -> Luminárias
#
# Índice 443: Rubim
#
# Índice 444: Rio Espera
#
#     Colisão -> Santa Vitória
#
# Índice 445: Central de Minas
#
#     Colisão -> Coração de Jesus
#
# Índice 447: Olímpio Noronha
#
# Índice 448: Angelândia
#
#     Colisão -> São Vicente de Minas
#
# Índice 449: Campos Altos
#
#     Colisão -> Pavão
#
# Índice 450: Jampruca
#
# Índice 452: São Brás do Suaçuí
#
# Índice 454: Santa Fé de Minas
#
# Índice 455: Ibitiúra de Minas
#
#     Colisão -> Presidente Kubitschek
#
#     Colisão -> Natércia
#
# Índice 459: Barbacena
#
#     Colisão -> Ingaí
#
# Índice 467: Gameleiras
#
# Índice 469: Caeté
#
# Índice 471: Itamarati de Minas
#
# Índice 472: Chapada Gaúcha
#
# Índice 473: Ibirité
#
#     Colisão -> Serra da Saudade
#
# Índice 474: Itacarambi
#
# Índice 475: Marilac
#
# Índice 476: Bambuí
#
#     Colisão -> Jenipapo de Minas
#
# Índice 477: Carmo da Mata
#
# Índice 478: Laranjal
#
# Índice 479: Paiva
#
#     Colisão -> Pedra Bonita
#
# Índice 480: Rio Doce
#
#     Colisão -> Vazante
#
#     Colisão -> Tiros
#
# Índice 481: Águas Vermelhas
#
#     Colisão -> Três Pontas
#
#     Colisão -> Cássia
#
# Índice 484: Fama
#
#     Colisão -> Tupaciguara
#
# Índice 485: Jaguaraçu
#
# Índice 487: Ipuiúna
#
#     Colisão -> Virgínia
#
#     Colisão -> Várzea da Palma
#
# Índice 488: Bonito de Minas
#
#     Colisão -> Onça de Pitangui
#
# Índice 493: São Thomé das Letras
#
# Índice 494: Serra do Salitre
#
# Índice 496: Alto Rio Doce
#
# Índice 500: Paineiras
#
# Índice 501: Brumadinho
#
#     Colisão -> Miradouro
#
# Índice 504: Coronel Pacheco
#
#     Colisão -> Lagoa Dourada
#
# Índice 505: São Sebastião do Anta
#
# Índice 506: Sabará
#
#     Colisão -> Santa Rita de Caldas
#
# Índice 508: Minduri
#
# Índice 510: Bom Jardim de Minas
#
#     Colisão -> São Sebastião do Paraíso
#
#     Colisão -> Cabeceira Grande
#
# Índice 511: Santa Rita de Minas
#
# Índice 513: Lamim
#
#     Colisão -> Senador Cortes
#
# Índice 514: Curvelo
#
# Índice 517: Lambari
#
#     Colisão -> Riacho dos Machados
#
#     Colisão -> Lontra
#
# Índice 524: Capela Nova
#
# Índice 525: Simonésia
#
# Índice 526: Pai Pedro
#
#     Colisão -> São João do Paraíso
#
# Índice 529: Sete Lagoas
#
# Índice 531: Bandeira do Sul
#
#     Colisão -> Pimenta
#
# Índice 532: Bom Jesus do Galho
#
#     Colisão -> Joaíma
#
# Índice 538: Diogo de Vasconcelos
#
# Índice 539: Itaguara
#
#     Colisão -> Piraúba
#
#     Colisão -> Peçanha
#
# Índice 540: Barra Longa
#
# Índice 541: Canaã
#
# Índice 542: Heliodora
#
# Índice 544: Itambé do Mato Dentro
#
# Índice 545: Divino
#
#     Colisão -> São José do Jacuri
#
#     Colisão -> Jequeri
#
# Índice 546: Ladainha
#
#     Colisão -> Urucânia
#
# Índice 547: Ressaquinha
#
# Índice 549: Ouro Branco
#
#     Colisão -> São João Evangelista
#
# Índice 550: Piranguinho
#
# Índice 551: Alfenas
#
#     Colisão -> Santa Luzia
#
# Índice 552: Carmo do Rio Claro
#
# Índice 553: São Sebastião do Maranhão
#
# Índice 554: Buritizeiro
#
#     Colisão -> Cachoeira de Pajeú
#
# Índice 555: Camacho
#
#     Colisão -> Frei Inocêncio
#
# Índice 556: Pedralva
#
# Índice 558: Estrela do Sul
#
# Índice 560: Santana dos Montes
#
# Índice 562: São Francisco de Sales
#
# Índice 563: Jaboticatubas
#
#     Colisão -> Santa Efigênia de Minas
#
# Índice 564: Nova Porteirinha
#
# Índice 565: Manhuaçu
#
# Índice 566: Volta Grande
#
# Índice 567: Itapecerica
#
#     Colisão -> Leopoldina
#
# Índice 568: Capitólio
#
# Índice 570: Medina
#
# Índice 571: Tabuleiro
#
# Índice 572: Lagoa Santa
#
#     Colisão -> Santa Maria do Suaçuí
#
# Índice 573: Timóteo
#
#     Colisão -> Varzelândia
#
# Índice 576: Carmo da Cachoeira
#
# Índice 577: Poté
#
# Índice 578: Caranaíba
#
#     Colisão -> Estiva
#
# Índice 579: Iturama
#
# Índice 580: Carmo do Cajuru
#
#     Colisão -> Pouso Alegre
#
#     Colisão -> Moeda
#
# Índice 581: Carlos Chagas
#
# Índice 582: Guaraciama
#
# Índice 583: Poço Fundo
#
# Índice 584: Vermelho Novo
#
# Índice 586: Chalé
#
# Índice 587: Claraval
#
#     Colisão -> Dores de Guanhães
#
# Índice 588: Itanhomi
#
#     Colisão -> Seritinga
#
# Índice 591: Mutum
#
# Índice 595: Moema
#
# Índice 596: Inimutaba
#
#     Colisão -> Monte Santo de Minas
#
# Índice 597: Capetinga
#
#     Colisão -> Divinolândia de Minas
#
# Índice 599: Presidente Olegário
#
# Índice 601: Pequeri
#
# Índice 602: Aiuruoca
#
#     Colisão -> Santana do Manhuaçu
#
#     Colisão -> Porteirinha
#
# Índice 607: Piumhi
#
#     Colisão -> Santana de Cataguases
#
#     Colisão -> Ponte Nova
#
# Índice 609: Montes Claros
#
# Índice 610: Oliveira
#
#     Colisão -> Silvianópolis
#
# Índice 611: Teófilo Otoni
#
# Índice 612: Botelhos
#
# Índice 615: Iguatama
#
#     Colisão -> Matozinhos
#
# Índice 617: Nazareno
#
#     Colisão -> São José da Barra
#
# Índice 621: Campos Gerais
#
#     Colisão -> Montezuma
#
# Índice 622: Bom Jesus da Penha
#
#     Colisão -> Dona Eusébia
#
# Índice 623: Novo Cruzeiro
#
# Índice 626: São Pedro do Suaçuí
#
# Índice 631: Pirajuba
#
# Índice 632: Aracitaba
#
#     Colisão -> Doresópolis
#
# Índice 633: Douradoquara
#
# Índice 637: Frutal
#
# Índice 638: Pedra Dourada
#
#     Colisão -> Simão Pereira
#
# Índice 639: Divisópolis
#
#     Colisão -> Raul Soares
#
# Índice 640: Goianá
#
#     Colisão -> Inhaúma
#
# Índice 641: Chapada do Norte
#
#     Colisão -> Piedade de Caratinga
#
# Índice 642: Luislândia
#
# Índice 643: São José do Alegre
#
# Índice 644: Monte Carmelo
#
# Índice 645: Guidoval
#
#     Colisão -> Maria da Fé
#
#     Colisão -> Icaraí de Minas
#
# Índice 647: Datas
#
#     Colisão -> Guimarânia
#
# Índice 651: Astolfo Dutra
#
#     Colisão -> Guarani
#
# Índice 653: Andradas
#
# Índice 655: Itabirinha
#
# Índice 657: Acaiaca
#
#     Colisão -> Japaraíba
#
#     Colisão -> Fortaleza de Minas
#
# Índice 660: Manhumirim
#
# Índice 661: Cantagalo
#
#     Colisão -> Olaria
#
# Índice 665: Rio Acima
#
# Índice 666: Frei Lagonegro
#
#     Colisão -> Medeiros
#
# Índice 667: Ouro Verde de Minas
#
# Índice 670: Mantena
#
# Índice 671: Capitão Enéas
#
#     Colisão -> Palmópolis
#
#     Colisão -> Limeira do Oeste
#
# Índice 672: Bocaiuva
#
#     Colisão -> Juatuba
#
# Índice 673: Conceição da Aparecida
#
#     Colisão -> Visconde do Rio Branco
#
# Índice 674: Rio Pomba
#
#     Colisão -> Rio Vermelho
#
# Índice 675: Maripá de Minas
#
# Índice 680: Itapagipe
#
# Índice 681: Água Comprida
#
#     Colisão -> Itamarandiba
#
# Índice 682: São Gonçalo do Rio Preto
#
#     Colisão -> São Miguel do Anta
#
# Índice 683: Felício dos Santos
#
# Índice 684: Bela Vista de Minas
#
#     Colisão -> Patrocínio
#
#     Colisão -> Buritis
#
# Índice 686: Campo Azul
#
# Índice 687: Padre Paraíso
#
#     Colisão -> Sabinópolis
#
# Índice 688: Barão de Monte Alto
#
#     Colisão -> Leandro Ferreira
#
#     Colisão -> Brasilândia de Minas
#
# Índice 690: Abaeté
#
#     Colisão -> Nova Belém
#
# Índice 691: União de Minas
#
# Índice 692: Santa Bárbara do Tugúrio
#
# Índice 693: Rio Casca
#
# Índice 695: Coluna
#
#     Colisão -> Santa Cruz de Salinas
#
#     Colisão -> Periquito
#
# Índice 696: Mateus Leme
#
#     Colisão -> Uberlândia
#
#     Colisão -> São Roque de Minas
#
# Índice 698: São João do Oriente
#
# Índice 699: Bom Jesus do Amparo
#
#     Colisão -> Guarda-Mor
#
# Índice 700: Ipiaçu
#
#     Colisão -> Perdões
#
# Índice 701: Passos
#
# Índice 702: Campanha
#
#     Colisão -> Ouro Preto
#
#     Colisão -> Espinosa
#
# Índice 707: Baependi
#
# Índice 708: Antônio Prado de Minas
#
# Índice 709: Rio Novo
#
# Índice 710: Caputira
#
# Índice 711: Araponga
#
# Índice 712: Mirabela
#
# Índice 713: Senhora dos Remédios
#
# Índice 714: Mário Campos
#
# Índice 715: Naque
#
# Índice 717: Nova Resende
#
#     Colisão -> Santo Antônio do Retiro
#
#     Colisão -> Rio Paranaíba
#
#     Colisão -> Perdigão
#
# Índice 718: Nova Ponte
#
# Índice 719: Minas Novas
#
# Índice 723: Carandaí
#
#     Colisão -> Estrela do Indaiá
#
# Índice 725: Pirapetinga
#
# Índice 727: Sericita
#
# Índice 728: Guaxupé
#
#     Colisão -> São Pedro dos Ferros
#
# Índice 729: Divisa Nova
#
# Índice 731: Miravânia
#
# Índice 735: Araxá
#
#     Colisão -> Ipanema
#
# Índice 737: Guaranésia
#
#     Colisão -> São Geraldo
#
# Índice 740: Berizal
#
# Índice 741: Entre Rios de Minas
#
#     Colisão -> Joanésia
#
# Índice 742: Bias Fortes
#
#     Colisão -> Ibiraci
#
#     Colisão -> Dores de Campos
#
# Índice 745: Lassance
#
# Índice 748: Campanário
#
#     Colisão -> Prudente de Morais
#
#     Colisão -> Piranguçu
#
#     Colisão -> Pedro Teixeira
#
# Índice 749: Dom Cavati
#
# Índice 750: Lajinha
#
#     Colisão -> São Gonçalo do Sapucaí
#
#     Colisão -> Planura
#
# Índice 751: Carmo de Minas
#
# Índice 752: Nacip Raydan
#
# Índice 753: Itajubá
#
#     Colisão -> Varginha
#
# Índice 756: Francisco Badaró
#
# Índice 757: Monte Formoso
#
# Índice 758: Santa Margarida
#
# Índice 759: Santa Rosa da Serra
#
# Índice 760: São Bento Abade
#
# Índice 765: Entre Folhas
#
# Índice 768: Itutinga
#
#     Colisão -> São Sebastião do Rio Preto
#
# Índice 770: Bugre
#
# Índice 771: Esmeraldas
#
# Índice 774: Borda da Mata
#
#     Colisão -> Rosário da Limeira
#
#     Colisão -> Caetanópolis
#
# Índice 775: Soledade de Minas
#
# Índice 777: Pedras de Maria da Cruz
#
# Índice 779: Pingo-d'Água
#
# Índice 782: Veredinha
#
# Índice 784: Fronteira
#
#     Colisão -> Madre de Deus de Minas
#
# Índice 786: Ipaba
#
# Índice 787: Santana do Riacho
#
# Índice 789: Silveirânia
#
# Índice 790: São Romão
#
# Índice 791: Nova Lima
#
# Índice 794: Campo Belo
#
#     Colisão -> Santa Cruz de Minas
#
# Índice 795: Baldim
#
#     Colisão -> Rio Preto
#
#     Colisão -> Raposos
#
# Índice 796: Araçuaí
#
#     Colisão -> São Sebastião da Vargem Alegre
#
# Índice 797: Patos de Minas
#
# Índice 798: Taparuba
#
# Índice 799: Córrego Novo
#
#     Colisão -> Santa Maria do Salto
#
# Índice 800: Alfredo Vasconcelos
#
# Índice 803: Itaúna
#
#     Colisão -> Veríssimo
#
# Índice 804: São João Nepomuceno
#
# Índice 809: Carvalhos
#
#     Colisão -> Jaíba
#
# Índice 810: Ewbank da Câmara
#
#     Colisão -> São José do Goiabal
#
# Índice 811: Dores do Indaiá
#
#     Colisão -> Monte Alegre de Minas
#
# Índice 813: Machado
#
#     Colisão -> Ubaporanga
#
#     Colisão -> Morro do Pilar
#
# Índice 815: Abre-Campo
#
# Índice 816: Cordisburgo
#
# Índice 817: Conquista
#
#     Colisão -> São Geraldo da Piedade
#
# Índice 818: Sacramento
#
# Índice 819: Galileia
#
#     Colisão -> Pratápolis
#
# Índice 820: Urucuia
#
# Índice 821: Ijaci
#
# Índice 822: Carrancas
#
# Índice 823: Cachoeira da Prata
#
# Índice 824: Felisburgo
#
# Índice 825: Descoberto
#
# Índice 827: Lagamar
#
#     Colisão -> Três Marias
#
#     Colisão -> Munhoz
#
# Índice 828: Pedrinópolis
#
#     Colisão -> São João Batista do Glória
#
# Índice 829: Piracema
#
#     Colisão -> São Tiago
#
# Índice 832: Ferros
#
#     Colisão -> Rio do Prado
#
# Índice 833: Itacambira
#
# Índice 835: Pedra do Indaiá
#
#     Colisão -> São José da Varginha
#
# Índice 836: Mamonas
#
#     Colisão -> Pitangui
#
# Índice 837: Ituiutaba
#
# Índice 838: Catuti
#
#     Colisão -> Santa Bárbara
#
# Índice 839: Barão de Cocais
#
#     Colisão -> Ibertioga
#
# Índice 840: Itinga
#
# Índice 841: Consolação
#
# Índice 842: Centralina
#
#     Colisão -> Mercês
#
#     Colisão -> Itamonte
#
# Índice 843: Belo Horizonte
#
#     Colisão -> Passa-Quatro
#
# Índice 844: Vargem Alegre
#
# Índice 845: Carangola
#
#     Colisão -> Santana do Jacaré
#
#     Colisão -> Cristina
#
# Índice 847: Extrema
#
#     Colisão -> Santana do Paraíso
#
# Índice 848: Itabirito
#
# Índice 849: Itaobim
#
#     Colisão -> Uberaba
#
#     Colisão -> São Domingos do Prata
#
# Índice 851: Materlândia
#
# Índice 852: Paraopeba
#
# Índice 853: Conselheiro Lafaiete
#
# Índice 855: Congonhas
#
# Índice 856: Alterosa
#
#     Colisão -> Prados
#
#     Colisão -> Conceição das Pedras
#
# Índice 0: Capim Branco
#
#     Colisão -> Santo Antônio do Grama
#
# Índice 1: Aracitaba
#
#     Colisão -> Rio Paranaíba
#
# Índice 2: Canaã
#
#     Colisão -> Dores de Campos
#
# Índice 3: Belmiro Braga
#
# Índice 4: Cláudio
#
#     Colisão -> Sete Lagoas
#
#     Colisão -> São Tiago
#
#     Colisão -> Cordislândia
#
# Índice 6: Jacutinga
#
#     Colisão -> Tiros
#
#     Colisão -> Ponto dos Volantes
#
# Índice 7: Desterro de Entre Rios
#
#     Colisão -> Frei Inocêncio
#
# Índice 8: Santana do Garambéu
#
# Índice 10: Antônio Carlos
#
# Índice 13: Jenipapo de Minas
#
# Índice 15: Fama
#
#     Colisão -> Presidente Bernardes
#
# Índice 16: Guaraciama
#
#     Colisão -> Santa Bárbara do Tugúrio
#
# Índice 19: Ervália
#
#     Colisão -> Paraguaçu
#
# Índice 21: Francisco Badaró
#
# Índice 23: Cristália
#
#     Colisão -> São Francisco de Sales
#
# Índice 24: Água Boa
#
# Índice 25: Pimenta
#
# Índice 32: Catas Altas da Noruega
#
# Índice 33: Itapecerica
#
#     Colisão -> Taparuba
#
# Índice 37: Jequitinhonha
#
# Índice 38: São Gonçalo do Rio Preto
#
#     Colisão -> Vargem Grande do Rio Pardo
#
# Índice 39: João Pinheiro
#
#     Colisão -> Tarumirim
#
# Índice 40: Peçanha
#
# Índice 41: Chácara
#
#     Colisão -> Serrania
#
# Índice 42: Dom Viçoso
#
#     Colisão -> São Francisco de Paula
#
# Índice 43: Monte Carmelo
#
#     Colisão -> Santo Antônio do Monte
#
# Índice 44: Itamogi
#
# Índice 46: Curral de Dentro
#
#     Colisão -> Santa Rita do Itueto
#
# Índice 47: Pai Pedro
#
# Índice 51: Passos
#
# Índice 52: Lassance
#
# Índice 53: Bicas
#
#     Colisão -> São José do Mantimento
#
# Índice 54: Natalândia
#
#     Colisão -> Tocantins
#
#     Colisão -> Salto da Divisa
#
# Índice 57: Espinosa
#
#     Colisão -> São Sebastião do Rio Preto
#
# Índice 58: Santo Antônio do Amparo
#
#     Colisão -> São Francisco
#
# Índice 59: Alfredo Vasconcelos
#
#     Colisão -> Jacuí
#
#     Colisão -> Capelinha
#
# Índice 60: Prata
#
# Índice 61: Heliodora
#
# Índice 62: Maravilhas
#
#     Colisão -> Silvianópolis
#
# Índice 66: Marmelópolis
#
# Índice 68: Campanário
#
# Índice 69: Januária
#
# Índice 70: Ipiaçu
#
# Índice 72: Santana dos Montes
#
#     Colisão -> São Pedro do Suaçuí
#
# Índice 73: Funilândia
#
# Índice 74: Serra do Salitre
#
# Índice 75: Mar de Espanha
#
# Índice 79: Alagoa
#
#     Colisão -> Virginópolis
#
#     Colisão -> Pedras de Maria da Cruz
#
#     Colisão -> Cruzeiro da Fortaleza
#
# Índice 81: Inhapim
#
# Índice 82: Tapiraí
#
# Índice 84: Frei Lagonegro
#
#     Colisão -> Uberaba
#
#     Colisão -> Serranópolis de Minas
#
# Índice 85: Fortuna de Minas
#
# Índice 86: Porto Firme
#
#     Colisão -> Rubelita
#
# Índice 87: São Tomás de Aquino
#
# Índice 89: Grão Mogol
#
#     Colisão -> Nova Porteirinha
#
# Índice 90: Simão Pereira
#
#     Colisão -> Taiobeiras
#
# Índice 91: Bertópolis
#
#     Colisão -> São José do Goiabal
#
#     Colisão -> Pedrinópolis
#
#     Colisão -> Chalé
#
# Índice 92: Jacinto
#
#     Colisão -> Taquaraçu de Minas
#
#     Colisão -> Senador Cortes
#
#     Colisão -> Nova União
#
# Índice 93: Caratinga
#
#     Colisão -> Eugenópolis
#
# Índice 94: Luislândia
#
# Índice 95: Catas Altas
#
#     Colisão -> São João da Ponte
#
# Índice 96: Virgolândia
#
# Índice 97: Veredinha
#
# Índice 98: São Francisco do Glória
#
# Índice 100: Jampruca
#
#     Colisão -> Tumiritinga
#
# Índice 101: Iturama
#
#     Colisão -> Perdizes
#
#     Colisão -> Miradouro
#
# Índice 102: Conceição das Alagoas
#
#     Colisão -> Rio Vermelho
#
# Índice 103: Varginha
#
# Índice 104: Prudente de Morais
#
# Índice 105: Amparo da Serra
#
#     Colisão -> Pavão
#
#     Colisão -> Itabirito
#
# Índice 106: São José da Safira
#
# Índice 108: Tupaciguara
#
# Índice 110: Luminárias
#
# Índice 111: Lagoa da Prata
#
# Índice 114: Guanhães
#
#     Colisão -> Liberdade
#
# Índice 116: Belo Horizonte
#
#     Colisão -> Papagaios
#
#     Colisão -> Cristais
#
# Índice 118: Itacambira
#
# Índice 119: Paula Cândido
#
# Índice 120: Andrelândia
#
#     Colisão -> Rio Espera
#
# Índice 121: Manhumirim
#
# Índice 122: Marliéria
#
# Índice 124: Carandaí
#
#     Colisão -> Olhos-d'Água
#
# Índice 126: Onça de Pitangui
#
# Índice 127: Durandé
#
#     Colisão -> Ubaporanga
#
# Índice 130: Santa Bárbara do Leste
#
#     Colisão -> Verdelândia
#
# Índice 131: Carvalhópolis
#
# Índice 132: Carmo do Cajuru
#
#     Colisão -> Florestal
#
# Índice 133: Faria Lemos
#
#     Colisão -> São Gonçalo do Pará
#
#     Colisão -> Piedade dos Gerais
#
# Índice 134: Patis
#
# Índice 135: Bom Repouso
#
#     Colisão -> Tocos do Moji
#
# Índice 136: Delfinópolis
#
# Índice 138: Jequeri
#
# Índice 140: Francisco Dumont
#
# Índice 141: Santa Maria do Suaçuí
#
# Índice 142: Piranguinho
#
# Índice 145: Virgem da Lapa
#
# Índice 146: Mercês
#
# Índice 149: Reduto
#
# Índice 150: Carmo de Minas
#
#     Colisão -> Morada Nova de Minas
#
#     Colisão -> Divisa Alegre
#
#     Colisão -> Conquista
#
# Índice 154: Goiabeira
#
#     Colisão -> Senador Modestino Gonçalves
#
# Índice 157: Capitão Andrade
#
# Índice 158: Leme do Prado
#
#     Colisão -> Monjolos
#
# Índice 160: Timóteo
#
#     Colisão -> Volta Grande
#
# Índice 161: Resplendor
#
# Índice 162: Araguari
#
#     Colisão -> São João do Manteninha
#
#     Colisão -> Piedade do Rio Grande
#
# Índice 164: São João Nepomuceno
#
# Índice 165: Quartel Geral
#
# Índice 167: Dom Bosco
#
# Índice 168: Naque
#
# Índice 170: Joaquim Felício
#
#     Colisão -> Santo Antônio do Retiro
#
#     Colisão -> Mateus Leme
#
# Índice 172: Passa Tempo
#
#     Colisão -> Soledade de Minas
#
# Índice 173: Padre Paraíso
#
# Índice 175: Cristiano Otoni
#
# Índice 176: Janaúba
#
# Índice 179: Miravânia
#
# Índice 182: Gonzaga
#
#     Colisão -> José Gonçalves de Minas
#
#     Colisão -> Itabirinha
#
# Índice 183: Santana do Jacaré
#
#     Colisão -> São Joaquim de Bicas
#
#     Colisão -> São Brás do Suaçuí
#
# Índice 185: Itanhomi
#
# Índice 186: Careaçu
#
#     Colisão -> Santana do Deserto
#
# Índice 187: Catuji
#
#     Colisão -> Jordânia
#
# Índice 188: Santo Antônio do Aventureiro
#
# Índice 191: Arinos
#
#     Colisão -> São João do Pacuí
#
#     Colisão -> Mantena
#
#     Colisão -> Bonfinópolis de Minas
#
# Índice 192: Wenceslau Braz
# Índice 193: Estrela do Indaiá
#
# Índice 194: São José da Lapa
#
# Índice 198: Engenheiro Navarro
#
# Índice 200: Canápolis
#
#     Colisão -> Ituiutaba
#
# Índice 202: Maripá de Minas
#
# Índice 203: Carmésia
#
#     Colisão -> Serro
#
# Índice 204: Formiga
#
# Índice 206: Argirita
#
#     Colisão -> Camacho
#
# Índice 208: Dionísio
#
#     Colisão -> Visconde do Rio Branco
#
# Índice 210: Antônio Dias
#
# Índice 211: Setubinha
#
# Índice 212: Areado
#
#     Colisão -> São José do Jacuri
#
# Índice 215: São Thomé das Letras
#
# Índice 216: Monte Belo
#
# Índice 217: Berizal
#
#     Colisão -> Caldas
#
# Índice 218: Matutina
#
# Índice 220: Matias Barbosa
#
# Índice 221: Mamonas
#
# Índice 222: Astolfo Dutra
#
# Índice 225: Montezuma
#
#     Colisão -> Pará de Minas
#
# Índice 226: Espírito Santo do Dourado
#
#     Colisão -> Santa Cruz de Minas
#
# Índice 227: Candeias
#
#     Colisão -> Tiradentes
#
#     Colisão -> Pratinha
#
# Índice 228: Novo Oriente de Minas
#
# Índice 229: Campanha
#
#     Colisão -> São Geraldo da Piedade
#
# Índice 230: Caetanópolis
#
# Índice 231: Coimbra
#
#     Colisão -> Urucânia
#
# Índice 233: Alvarenga
#
#     Colisão -> Bueno Brandão
#
# Índice 236: Alpercata
#
# Índice 238: Mendes Pimentel
#
# Índice 239: Campo Florido
#
#     Colisão -> Jaboticatubas
#
# Índice 240: Botumirim
#
# Índice 243: Fervedouro
#
#     Colisão -> Senador Amaral
#
#     Colisão -> Natércia
#
# Índice 244: Confins
#
#     Colisão -> Ipuiúna
#
# Índice 245: Capitólio
#
#     Colisão -> São João do Manhuaçu
#
# Índice 246: Carmo da Mata
#
# Índice 247: Chapada do Norte
#
# Índice 248: Bom Jardim de Minas
#
#     Colisão -> Santos Dumont
#
#     Colisão -> Pedro Teixeira
#
#     Colisão -> Itapeva
#
# Índice 250: Alvorada de Minas
#
# Índice 252: Andradas
#
#     Colisão -> Itacarambi
#
# Índice 253: Felício dos Santos
#
#     Colisão -> São Lourenço
#
# Índice 254: Bom Despacho
#
#     Colisão -> Gameleiras
#
# Índice 255: Divinolândia de Minas
#
#     Colisão -> Toledo
#
# Índice 256: Fronteira dos Vales
#
#     Colisão -> Pirapora
#
# Índice 257: Juiz de Fora
#
# Índice 261: Iraí de Minas
#
#     Colisão -> São José da Varginha
#
# Índice 263: Barroso
#
# Índice 264: Contagem
#
# Índice 265: Alto Rio Doce
#
# Índice 267: São Sebastião da Vargem Alegre
#
# Índice 269: Sabinópolis
#
# Índice 270: Recreio
#
#     Colisão -> São João del-Rei
#
# Índice 272: Simonésia
#
# Índice 274: Madre de Deus de Minas
#
#     Colisão -> São José da Barra
#
# Índice 277: São Gonçalo do Sapucaí
#
# Índice 279: Serranos
#
# Índice 280: Nanuque
#
# Índice 281: Bonito de Minas
#
# Índice 284: Leandro Ferreira
#
#     Colisão -> Santa Margarida
#
#     Colisão -> Perdões
#
# Índice 285: Buritizeiro
#
# Índice 286: Abaeté
#
# Índice 287: Córrego Danta
#
# Índice 291: Conceição do Mato Dentro
#
#     Colisão -> Ouro Verde de Minas
#
# Índice 293: Dona Eusébia
#
# Índice 294: Betim
#
# Índice 295: Brás Pires
#
#     Colisão -> Guarani
#
# Índice 296: São Romão
#
# Índice 298: Juramento
#
#     Colisão -> Morro do Pilar
#
# Índice 299: Pedra do Anta
#
# Índice 300: São Félix de Minas
#
# Índice 301: Ubaí
#
# Índice 305: Senhora de Oliveira
#
# Índice 306: Berilo
#
#     Colisão -> São Sebastião do Maranhão
#
#     Colisão -> Monte Alegre de Minas
#
# Índice 307: Brasília de Minas
#
# Índice 311: Arantina
#
#     Colisão -> Catuti
#
# Índice 312: São Gotardo
#
#     Colisão -> São João Evangelista
#
# Índice 313: Medeiros
#
#     Colisão -> Olímpio Noronha
#
# Índice 317: Piranguçu
#
# Índice 319: Bocaiuva
#
#     Colisão -> Turvolândia
#
#     Colisão -> Cambuquira
#
# Índice 323: Japonvar
#
#     Colisão -> Teófilo Otoni
#
# Índice 325: Nova Belém
#
#     Colisão -> Santana de Pirapama
#
# Índice 327: Machacalis
#
#     Colisão -> Pequi
#
# Índice 329: Juruaia
#
#     Colisão -> São Sebastião da Bela Vista
#
# Índice 330: Conceição do Pará
#
# Índice 331: Martins Soares
#
#     Colisão -> Monte Azul
#
# Índice 332: Aiuruoca
#
#     Colisão -> Pedra Azul
#
# Índice 333: Cássia
#
#     Colisão -> Santa Rita de Minas
#
# Índice 334: Carvalhos
#
# Índice 335: Monsenhor Paulo
#
# Índice 337: Araponga
#
# Índice 338: Lagoa Formosa
#
# Índice 339: Jequitaí
#
#     Colisão -> São Geraldo
#
# Índice 340: Aguanil
#
# Índice 341: Palma
#
# Índice 342: Franciscópolis
#
# Índice 343: Carmópolis de Minas
#
#     Colisão -> Raul Soares
#
#     Colisão -> Raposos
#
# Índice 344: Ipaba
#
# Índice 345: Braúnas
#
#     Colisão -> Sarzedo
#
# Índice 346: São João da Lagoa
#
# Índice 347: Coromandel
#
#     Colisão -> Rio Pomba
#
# Índice 348: Materlândia
#
# Índice 349: Unaí
#
# Índice 350: Felixlândia
#
#     Colisão -> São Domingos das Dores
#
#     Colisão -> Rio Novo
#
# Índice 351: Presidente Olegário
#
#     Colisão -> Veríssimo
#
#     Colisão -> São Pedro da União
#
# Índice 352: Marilac
#
# Índice 353: Botelhos
#
# Índice 356: Lamim
#
# Índice 357: Divino
#
# Índice 359: Cana Verde
#
#     Colisão -> Ferros
#
#     Colisão -> Capetinga
#
# Índice 360: Vespasiano
#
# Índice 361: Córrego Novo
#
#     Colisão -> Esmeraldas
#
# Índice 362: Cordisburgo
#
#     Colisão -> Cristina
#
# Índice 363: Entre Rios de Minas
#
#     Colisão -> Varzelândia
#
#     Colisão -> Matozinhos
#
# Índice 364: Tabuleiro
#
# Índice 367: Mutum
#
#     Colisão -> Nova Lima
#
# Índice 369: Itatiaiuçu
#
#     Colisão -> Japaraíba
#
# Índice 370: Campestre
#
# Índice 372: Bandeira do Sul
#
# Índice 374: Aimorés
#
#     Colisão -> Pedralva
#
# Índice 375: Santa Fé de Minas
#
# Índice 377: Bom Jesus do Galho
#
#     Colisão -> Pains
#
# Índice 378: Barão de Monte Alto
#
# Índice 380: Barão de Cocais
#
#     Colisão -> Belo Oriente
#
# Índice 383: Nova Serrana
#
# Índice 385: Brumadinho
#
# Índice 386: Gouveia
#
# Índice 387: Guiricema
#
#     Colisão -> Riacho dos Machados
#
# Índice 388: Consolação
#
#     Colisão -> Teixeiras
#
#     Colisão -> Sardoá
#
#     Colisão -> Pedra Dourada
#
# Índice 390: Águas Vermelhas
#
#     Colisão -> Itueta
#
#     Colisão -> Icaraí de Minas
#
# Índice 391: Santa Rita de Ibitipoca
#
# Índice 394: Coronel Xavier Chaves
#
#     Colisão -> Santo Hipólito
#
# Índice 395: Bom Jesus da Penha
#
# Índice 396: Couto de Magalhães de Minas
#
#     Colisão -> São Sebastião do Paraíso
#
#     Colisão -> Pescador
#
# Índice 397: Pouso Alto
#
#     Colisão -> Presidente Kubitschek
#
# Índice 398: Nova Resende
#
# Índice 400: Araporã
#
#     Colisão -> Santana do Riacho
#
#     Colisão -> Rio Doce
#
#     Colisão -> Riachinho
#
#     Colisão -> Bias Fortes
#
# Índice 401: Orizânia
#
# Índice 402: Coroaci
#
#     Colisão -> Sapucaí-Mirim
#
#     Colisão -> Itaguara
#
# Índice 405: São Miguel do Anta
#
# Índice 406: Itambé do Mato Dentro
#
# Índice 407: Ribeirão das Neves
#
#     Colisão -> Sobrália
#
# Índice 408: Cachoeira de Pajeú
#
# Índice 409: Conceição do Rio Verde
#
#     Colisão -> Tapira
#
#     Colisão -> Santo Antônio do Itambé
#
# Índice 410: Açucena
#
#     Colisão -> Jesuânia
#
# Índice 411: Novorizonte
#
#     Colisão -> São Roque de Minas
#
# Índice 414: Brasilândia de Minas
#
# Índice 415: Capela Nova
#
#     Colisão -> Maria da Fé
#
#     Colisão -> Cascalho Rico
#
# Índice 416: Arapuá
#
#     Colisão -> Campo do Meio
#
# Índice 418: Capinópolis
#
#     Colisão -> São Pedro dos Ferros
#
#     Colisão -> Jeceaba
#
# Índice 420: Santo Antônio do Jacinto
#
# Índice 421: Baependi
#
# Índice 423: Dores do Turvo
#
#     Colisão -> São Gonçalo do Abaeté
#
#     Colisão -> Olaria
#
#     Colisão -> Ijaci
#
# Índice 424: Paracatu
#
# Índice 426: Dom Cavati
#
#     Colisão -> Seritinga
#
# Índice 427: Leopoldina
#
# Índice 428: Montes Claros
#
# Índice 429: Ipatinga
#
#     Colisão -> Pequeri
#
# Índice 430: Divinésia
#
#     Colisão -> Ninheira
#
# Índice 431: Pedra do Indaiá
#
# Índice 432: Piraúba
#
# Índice 433: Além Paraíba
#
#     Colisão -> Indianópolis
#
# Índice 434: Prados
#
#     Colisão -> Várzea da Palma
#
# Índice 435: Jaguaraçu
#
#     Colisão -> Piracema
#
# Índice 436: Mesquita
#
# Índice 437: Cachoeira de Minas
#
#     Colisão -> Lima Duarte
#
# Índice 438: Campos Altos
#
# Índice 439: Santo Antônio do Rio Abaixo
#
#     Colisão -> São João das Missões
#
# Índice 440: Guimarânia
#
# Índice 441: Camanducaia
#
# Índice 443: Itaverava
#
# Índice 444: Paraisópolis
#
#     Colisão -> Paraopeba
#
# Índice 445: Oliveira
#
# Índice 446: Fortaleza de Minas
#
# Índice 447: Almenara
#
#     Colisão -> Ubá
#
#     Colisão -> Limeira do Oeste
#
# Índice 450: Piau
#
# Índice 451: Datas
#
# Índice 452: Fernandes Tourinho
#
# Índice 453: Congonhas
#
# Índice 454: Bandeira
#
# Índice 456: Patrocínio
#
#     Colisão -> Rio Manso
#
# Índice 457: Passa-Vinte
#
# Índice 461: Bela Vista de Minas
#
# Índice 462: Salinas
#
# Índice 464: Araxá
#
# Índice 465: Carrancas
#
#     Colisão -> Crisólita
#
# Índice 466: Claro dos Poções
#
#     Colisão -> Santa Rita de Jacutinga
#
#     Colisão -> Elói Mendes
#
# Índice 468: Inimutaba
#
# Índice 470: Pouso Alegre
#
# Índice 472: Rodeiro
#
# Índice 476: Caiana
#
# Índice 478: Desterro do Melo
#
# Índice 481: Rio Preto
#
# Índice 483: Araçaí
#
#     Colisão -> Juvenília
#
# Índice 485: Abadia dos Dourados
#
#     Colisão -> Pintópolis
#
#     Colisão -> Lontra
#
#     Colisão -> Jaíba
#
# Índice 486: Nova Ponte
#
# Índice 487: Juatuba
#
#     Colisão -> Ressaquinha
#
# Índice 489: Nova Era
#
# Índice 490: Divisa Nova
#
# Índice 491: Itamarandiba
#
# Índice 492: Viçosa
#
# Índice 493: Conselheiro Pena
#
# Índice 494: Dores de Guanhães
#
# Índice 495: Sacramento
#
# Índice 496: Francisco Sá
#
#     Colisão -> São Domingos do Prata
#
#     Colisão -> Piedade de Ponte Nova
#
#     Colisão -> Medina
#
# Índice 497: Lagoa Dourada
#
#     Colisão -> São Vicente de Minas
#
#     Colisão -> Muriaé
#
# Índice 499: Itapagipe
#
#     Colisão -> Lambari
#
# Índice 500: Ouro Fino
#
# Índice 501: Guidoval
#
# Índice 502: Santa Maria de Itabira
#
# Índice 504: Carmo da Cachoeira
#
# Índice 506: Caranaíba
#
# Índice 507: Mathias Lobato
#
#     Colisão -> Pratápolis
#
# Índice 508: Lagoa Santa
#
# Índice 509: Caxambu
#
#     Colisão -> Glaucilândia
#
#     Colisão -> Curvelo
#
# Índice 510: Campina Verde
#
# Índice 513: Cambuí
#
# Índice 514: Alfenas
#
#     Colisão -> Perdigão
#
#     Colisão -> Divino das Laranjeiras
#
# Índice 515: Novo Cruzeiro
#
# Índice 520: Corinto
#
#     Colisão -> Três Pontas
#
#     Colisão -> Estrela Dalva
#
# Índice 521: Bom Jesus do Amparo
#
# Índice 523: Ibiracatu
#
#     Colisão -> Nepomuceno
#
# Índice 524: Coração de Jesus
#
# Índice 526: Indaiabira
#
#     Colisão -> Santa Rita de Caldas
#
# Índice 527: Varjão de Minas
#
# Índice 528: Oliveira Fortes
#
#     Colisão -> Vargem Alegre
#
# Índice 532: Grupiara
#
#     Colisão -> Presidente Juscelino
#
# Índice 534: Ibertioga
#
# Índice 538: Pirapetinga
#
#     Colisão -> Serra Azul de Minas
#
# Índice 540: Iapu
#
#     Colisão -> Santa Vitória
#
# Índice 541: Alto Caparaó
#
#     Colisão -> Estiva
#
# Índice 542: Passabém
#
# Índice 544: Cajuri
#
# Índice 545: Estrela do Sul
#
# Índice 546: Barra Longa
#
#     Colisão -> Minduri
#
#     Colisão -> Central de Minas
#
# Índice 548: Divisópolis
#
#     Colisão -> Mário Campos
#
# Índice 549: Itinga
#
# Índice 550: Monte Santo de Minas
#
# Índice 552: Munhoz
#
# Índice 553: Itanhandu
#
#     Colisão -> Patos de Minas
#
# Índice 556: Ritápolis
#
# Índice 558: Engenheiro Caldas
#
# Índice 560: Gonçalves
#
# Índice 561: Piranga
#
# Índice 563: Casa Grande
#
# Índice 564: Abre-Campo
#
#     Colisão -> Mirabela
#
#     Colisão -> Cachoeira da Prata
#
#     Colisão -> Ataléia
#
# Índice 565: Vermelho Novo
#
# Índice 568: Santana do Manhuaçu
#
# Índice 570: Rosário da Limeira
#
# Índice 572: Santa Juliana
#
# Índice 576: Montalvânia
#
# Índice 577: Acaiaca
#
#     Colisão -> Extrema
#
# Índice 578: Douradoquara
#
# Índice 579: Cônego Marinho
#
# Índice 580: Frutal
#
# Índice 583: Delfim Moreira
#
# Índice 584: Água Comprida
#
# Índice 587: Gurinhatã
#
#     Colisão -> Romaria
#
# Índice 588: Itumirim
#
# Índice 589: Centralina
#
# Índice 590: Três Corações
#
# Índice 591: Carangola
#
#     Colisão -> Rio Casca
#
# Índice 594: Ingaí
#
# Índice 595: Poços de Caldas
#
# Índice 596: Rochedo de Minas
#
# Índice 597: Pirajuba
#
# Índice 600: Urucuia
#
# Índice 602: Capitão Enéas
#
# Índice 603: Conceição de Ipanema
#
# Índice 605: Bocaina de Minas
#
#     Colisão -> Chapada Gaúcha
#
# Índice 607: Claraval
#
# Índice 608: Minas Novas
#
#     Colisão -> São Geraldo do Baixio
#
# Índice 609: Guaxupé
#
# Índice 610: Santa Bárbara
#
#     Colisão -> São José do Alegre
#
# Índice 612: Congonhal
#
#     Colisão -> Descoberto
#
# Índice 613: Bambuí
#
# Índice 616: Ibituruna
#
#     Colisão -> Uruana de Minas
#
# Índice 617: Barbacena
#
#     Colisão -> Cipotânea
#
# Índice 618: Buritis
#
# Índice 619: Bugre
#
# Índice 621: Borda da Mata
#
# Índice 622: Governador Valadares
#
# Índice 626: Albertina
#
#     Colisão -> Cedro do Abaeté
#
# Índice 630: Coqueiral
#
# Índice 631: Ladainha
#
# Índice 632: Coronel Murta
#
#     Colisão -> Mato Verde
#
#     Colisão -> Manga
#
#     Colisão -> Ibiá
#
# Índice 633: Cabo Verde
#
# Índice 634: Poté
#
# Índice 636: Guaranésia
#
#     Colisão -> Patrocínio do Muriaé
#
#     Colisão -> Ilicínea
#
# Índice 637: Ribeirão Vermelho
#
# Índice 638: Pedro Leopoldo
#
# Índice 639: Guarda-Mor
#
# Índice 640: Cuparaque
#
#     Colisão -> Guaraciaba
#
# Índice 643: Felisburgo
#
# Índice 646: Serra dos Aimorés
#
# Índice 649: Rio do Prado
#
#     Colisão -> Umburatiba
#
# Índice 651: Lagamar
#
#     Colisão -> Moema
#
#     Colisão -> Mata Verde
#
# Índice 652: Santana de Cataguases
#
# Índice 655: Dores do Indaiá
#
#     Colisão -> Virgínia
#
# Índice 656: Ibirité
#
# Índice 658: Carbonita
#
#     Colisão -> Guapé
#
# Índice 659: Aricanduva
#
# Índice 660: Paulistas
#
# Índice 661: Comercinho
#
#     Colisão -> Diogo de Vasconcelos
#
# Índice 663: Planura
#
#     Colisão -> Sem-Peixe
#
# Índice 664: Santa Rosa da Serra
#
# Índice 665: Doresópolis
#
# Índice 666: Conselheiro Lafaiete
#
# Índice 667: Iguatama
#
#     Colisão -> Periquito
#
#     Colisão -> Nova Módica
#
# Índice 668: Conceição dos Ouros
#
# Índice 674: Córrego do Bom Jesus
#
# Índice 675: Boa Esperança
#
#     Colisão -> Cruzília
#
# Índice 676: Monte Formoso
#
# Índice 677: Chiador
#
# Índice 678: Igaratinga
#
# Índice 679: Crucilândia
#
# Índice 680: São Sebastião do Rio Verde
#
# Índice 681: Buenópolis
#
#     Colisão -> Três Marias
#
#     Colisão -> Luz
#
#     Colisão -> Inconfidentes
#
# Índice 682: Padre Carvalho
#
# Índice 684: Laranjal
#
# Índice 687: José Raydan
#
#     Colisão -> Santa Luzia
#
# Índice 689: Dom Joaquim
#
# Índice 691: Lavras
#
# Índice 697: Conceição da Aparecida
#
# Índice 698: Imbé de Minas
#
# Índice 699: Ibitiúra de Minas
#
# Índice 705: Congonhas do Norte
#
# Índice 706: Campo Belo
#
#     Colisão -> Piedade de Caratinga
#
# Índice 708: Itambacuri
#
# Índice 709: Araújos
#
# Índice 710: Biquinhas
#
#     Colisão -> Dom Silvério
#
# Índice 711: Sabará
#
#     Colisão -> São José do Divino
#
# Índice 712: Pitangui
#
# Índice 713: Caputira
#
# Índice 714: Passa-Quatro
#
# Índice 717: Morro da Garça
#
# Índice 719: Goianá
#
#     Colisão -> Nazareno
#
#     Colisão -> Itutinga
#
# Índice 720: Espera Feliz
#
# Índice 721: Paiva
#
# Índice 722: Antônio Prado de Minas
#
# Índice 723: Coluna
#
#     Colisão -> Vargem Bonita
#
#     Colisão -> Martinho Campos
#
# Índice 724: Itaobim
#
# Índice 725: Pocrane
#
# Índice 726: Santana do Paraíso
#
# Índice 731: Senador Firmino
#
# Índice 732: Rubim
#
# Índice 733: Itamarati de Minas
#
# Índice 734: Cataguases
#
# Índice 735: Divinópolis
#
#     Colisão -> Lajinha
#
#     Colisão -> Formoso
#
# Índice 736: Angelândia
#
# Índice 737: Brasópolis
#
#     Colisão -> Coronel Pacheco
#
# Índice 738: Carmo do Paranaíba
#
#     Colisão -> Josenópolis
#
# Índice 739: Pompéu
#
#     Colisão -> Vazante
#
#     Colisão -> Rio Piracicaba
#
# Índice 742: São Bento Abade
#
# Índice 743: Caparaó
#
#     Colisão -> Sericita
#
# Índice 744: Carmo do Rio Claro
#
# Índice 745: Machado
#
# Índice 748: Miraí
#
# Índice 749: Santa Maria do Salto
#
#     Colisão -> São João do Oriente
#
# Índice 750: Coronel Fabriciano
#
#     Colisão -> São Gonçalo do Rio Abaixo
#
# Índice 751: Igarapé
#
#     Colisão -> Santa Helena de Minas
#
# Índice 752: Arcos
#
# Índice 753: Rio Acima
#
#     Colisão -> Senhora do Porto
#
# Índice 754: São João Batista do Glória
#
#     Colisão -> União de Minas
#
# Índice 757: Oratórios
#
# Índice 758: Araçuaí
#
# Índice 760: Piumhi
#
# Índice 761: Ibiraci
#
# Índice 762: Ibiaí
#
# Índice 763: Fronteira
#
#     Colisão -> Porteirinha
#
#     Colisão -> Itaú de Minas
#
# Índice 764: Arceburgo
#
#     Colisão -> São João da Mata
#
#     Colisão -> Pingo-d'Água
#
# Índice 765: Malacacheta
#
# Índice 766: Cantagalo
#
# Índice 769: Joaíma
#
#     Colisão -> Senador José Bento
#
# Índice 770: Poço Fundo
#
# Índice 771: Bonfim
#
# Índice 772: Queluzito
#
#     Colisão -> Turmalina
#
# Índice 773: Galileia
#
#     Colisão -> Paineiras
#
# Índice 774: Frei Gaspar
#
# Índice 776: Ipanema
#
#     Colisão -> Tombos
#
#     Colisão -> Matipó
#
# Índice 777: Pedra Bonita
#
# Índice 779: Lagoa dos Patos
#
# Índice 780: Alpinópolis
#
#     Colisão -> Resende Costa
#
# Índice 781: Uberlândia
#
# Índice 783: Baldim
#
#     Colisão -> Ouro Preto
#
#     Colisão -> Luisburgo
#
# Índice 785: Santa Cruz de Salinas
#
# Índice 786: Alvinópolis
#
# Índice 787: Comendador Gomes
#
#     Colisão -> Santa Cruz do Escalvado
#
#     Colisão -> Rio Pardo de Minas
#
# Índice 788: Inhaúma
#
# Índice 789: Itaúna
#
# Índice 790: Campos Gerais
#
#     Colisão -> Palmópolis
#
# Índice 791: Senhora dos Remédios
#
# Índice 792: Nacip Raydan
#
# Índice 800: Cachoeira Dourada
#
#     Colisão -> Matias Cardoso
#
# Índice 801: Carneirinho
#
# Índice 802: Lagoa Grande
#
# Índice 803: Itabira
#
# Índice 804: Caeté
#
# Índice 807: Córrego Fundo
#
# Índice 808: Caraí
#
#     Colisão -> Monte Sião
#
#     Colisão -> Jequitibá
#
# Índice 809: São João do Paraíso
#
# Índice 812: Cabeceira Grande
#
# Índice 813: Carlos Chagas
#
# Índice 815: Mariana
#
# Índice 818: Conceição da Barra de Minas
#
# Índice 820: Ouro Branco
#
# Índice 821: Campo Azul
#
# Índice 822: Itamonte
#
#     Colisão -> Ponte Nova
#
# Índice 823: Manhuaçu
#
# Índice 828: Augusto de Lima
#
# Índice 829: Ewbank da Câmara
#
# Índice 830: Entre Folhas
#
#     Colisão -> Serra da Saudade
#
# Índice 834: Guarará
#
#     Colisão -> Santa Efigênia de Minas
#
# Índice 835: Belo Vale
#
# Índice 836: Delta
#
# Índice 837: Fruta de Leite
#
# Índice 839: Itajubá
#
# Índice 840: Águas Formosas
#
#     Colisão -> Joanésia
#
# Índice 842: Itaipé
#
#     Colisão -> São Sebastião do Oeste
#
# Índice 845: Santana da Vargem
#
# Índice 846: João Monlevade
#
#     Colisão -> Silveirânia
#
#     Colisão -> São Sebastião do Anta
#
#     Colisão -> Moeda
#
# Índice 847: Diamantina
#
# Índice 851: Vieiras
#
# Índice 852: Alto Jequitibá
#
#     Colisão -> Santa Rita do Sapucaí
#
#     Colisão -> Muzambinho
#
# Índice 853: Bom Sucesso
#
#     Colisão -> Santa Bárbara do Monte Verde
#
# Índice 856: Alterosa
#
#     Colisão -> Ponto Chique
#
# Índice 857: Conceição das Pedras
#
# Índice 4: Belo Oriente
#
# Índice 7: Engenheiro Caldas
#
# Índice 8: Pedras de Maria da Cruz
#
# Índice 9: Capitólio
#
#     Colisão -> Ingaí
#
# Índice 11: Jaguaraçu
#
# Índice 13: São Francisco do Glória
#
# Índice 14: Barra Longa
#
#     Colisão -> Ipuiúna
#
# Índice 15: Patis
#
# Índice 16: Guaraciama
#
# Índice 18: São João da Lagoa
#
# Índice 19: Matipó
#
# Índice 20: Araçaí
#
#     Colisão -> Montalvânia
#
#     Colisão -> Bocaina de Minas
#
#     Colisão -> Aricanduva
#
# Índice 21: Cana Verde
#
# Índice 23: Augusto de Lima
#
#     Colisão -> Passos
#
# Índice 24: Itamarati de Minas
#
#     Colisão -> Uruana de Minas
#
#     Colisão -> Rio Acima
#
#     Colisão -> Munhoz
#
# Índice 25: Onça de Pitangui
#
# Índice 26: Cambuí
#
# Índice 27: Araújos
#
# Índice 33: Leme do Prado
#
# Índice 34: Caranaíba
#
# Índice 36: Ibiaí
#
#     Colisão -> Naque
#
#     Colisão -> Itamarandiba
#
# Índice 37: Carlos Chagas
#
# Índice 38: Santana de Pirapama
#
# Índice 40: Toledo
#
# Índice 42: Bom Jesus da Penha
#
#     Colisão -> Monjolos
#
#     Colisão -> Juiz de Fora
#
#     Colisão -> Jeceaba
#
# Índice 43: Varginha
#
# Índice 44: Santa Rosa da Serra
#
# Índice 45: Ouro Preto
#
# Índice 46: Jacinto
#
#     Colisão -> Passa-Vinte
#
#     Colisão -> Jesuânia
#
# Índice 48: Reduto
#
# Índice 49: Taparuba
#
# Índice 51: Jequitibá
#
# Índice 53: Serra da Saudade
#
# Índice 55: Peçanha
#
#     Colisão -> Presidente Juscelino
#
# Índice 56: Comendador Gomes
#
#     Colisão -> Iturama
#
#     Colisão -> Itueta
#
# Índice 61: Espírito Santo do Dourado
#
#     Colisão -> Lagoa Dourada
#
# Índice 62: Camanducaia
#
# Índice 63: Catas Altas
#
#     Colisão -> São Pedro da União
#
# Índice 64: Bom Sucesso
#
#     Colisão -> Grão Mogol
#
# Índice 65: Campestre
#
# Índice 66: São João do Manteninha
#
# Índice 67: Buenópolis
#
# Índice 69: Moema
#
# Índice 70: Bom Despacho
#
#     Colisão -> Vieiras
#
#     Colisão -> Tiradentes
#
# Índice 71: Ervália
#
# Índice 72: Alvorada de Minas
#
#     Colisão -> Umburatiba
#
#     Colisão -> Itaguara
#
# Índice 74: Rio do Prado
#
# Índice 76: Paineiras
#
#     Colisão -> Ubá
#
#     Colisão -> Serra Azul de Minas
#
# Índice 77: Argirita
#
#     Colisão -> Pedro Teixeira
#
# ...
#
# Índice 625: Passa-Quatro
#
# Índice 628: Divino
#
# Índice 629: José Gonçalves de Minas
#
#     Colisão -> Lagoa Santa
#
# Índice 630: Bom Jardim de Minas
#
# Índice 631: Virgolândia
#
# Índice 633: Salto da Divisa
#
# Índice 640: Piranga
#
# Índice 642: Araxá
#
# Índice 644: Nacip Raydan
#
# Índice 645: Confins
#
# Índice 651: Santana da Vargem
#
# Índice 653: Carmo da Cachoeira
#
# Índice 654: Bom Jesus do Amparo
#
# Índice 657: São Gonçalo do Pará
#
# Índice 658: Pará de Minas
#
# Índice 659: Belo Horizonte
#
# Índice 661: Chapada do Norte
#
#     Colisão -> Ladainha
#
# Índice 662: Nepomuceno
#
# Índice 674: Carandaí
#
# Índice 676: Cachoeira Dourada
#
# Índice 679: Água Comprida
#
# Índice 680: Santa Rita de Jacutinga
#
# Índice 682: Jampruca
#
# Índice 684: Padre Paraíso
#
# Índice 686: Itajubá
#
# Índice 688: Jeceaba
#
# Índice 689: Dores de Campos
#
#     Colisão -> Luislândia
#
# Índice 691: Estrela do Sul
#
# Índice 696: São João Evangelista
#
# Índice 697: Matipó
#
# Índice 699: Conceição da Barra de Minas
#
# Índice 700: Campina Verde
#
# Índice 709: Toledo
#
# Índice 712: Matutina
#
# Índice 713: Pitangui
#
# Índice 714: Ouro Verde de Minas
#
# Índice 715: Berilo
#
# Índice 719: Romaria
#
# Índice 723: Uberlândia
#
# Índice 727: Senhora dos Remédios
#
# Índice 728: Jequitaí
#
# Índice 730: Bocaiuva
#
# Índice 735: Engenheiro Caldas
#
# Índice 737: Bonfim
#
#     Colisão -> Santana dos Montes
#
# Índice 744: Formiga
#
# Índice 750: Padre Carvalho
#
# Índice 751: Abaeté
#
# Índice 753: Felixlândia
#
# Índice 754: Brasópolis
#
# Índice 756: Araguari
#
# Índice 759: Capim Branco
#
# Índice 762: Itamarati de Minas
#
# Índice 763: Comendador Gomes
#
#     Colisão -> São Geraldo do Baixio
#
# Índice 764: Ponto Chique
#
# Índice 767: Ubaí
#
# Índice 769: Pratápolis
#
# Índice 770: Natércia
#
# Índice 773: União de Minas
#
# Índice 777: Piraúba
#
# Índice 779: Santana do Riacho
#
# Índice 781: Bom Sucesso
#
# Índice 782: Bocaina de Minas
#
#     Colisão -> São Gonçalo do Sapucaí
#
#     Colisão -> Corinto
#
# Índice 783: Icaraí de Minas
#
# Índice 787: Machacalis
#
# Índice 788: São João del-Rei
#
# Índice 795: Monte Sião
#
# Índice 798: Rio Pardo de Minas
#
# Índice 802: Iraí de Minas
#
# Índice 803: Cláudio
#
# Índice 804: Alvinópolis
#
# Índice 805: Jacinto
#
# Índice 808: Barra Longa
#
#     Colisão -> Raposos
#
# Índice 809: Novo Cruzeiro
#
# Índice 811: Alpinópolis
#
#     Colisão -> Ribeirão Vermelho
#
# Índice 813: Gonçalves
#
#     Colisão -> Monte Formoso
#
# Índice 816: Pequeri
#
# Índice 825: Mathias Lobato
#
# Índice 830: Campos Altos
#
#     Colisão -> Itinga
#
# Índice 833: São Domingos do Prata
#
# Índice 834: Cascalho Rico
#
# Índice 836: Passa-Vinte
#
# Índice 837: Lagoa Dourada
#
#     Colisão -> Passos
#
# Índice 842: Ibituruna
#
# Índice 844: Lagamar
#
# Índice 846: Divisa Nova
#
# Índice 851: Ibiracatu
#
# Índice 853: São Sebastião do Oeste
#
# Índice 854: Tupaciguara
#
# Índice 856: Carangola
#
# Índice 857: Cristina
#
#     Colisão -> Santa Efigênia de Minas
#
# Índice 860: Caetanópolis
#
# Índice 862: Carmópolis de Minas
#
# Índice 863: São João do Pacuí
#
# Índice 864: Alto Rio Doce
#
#     Colisão -> Resplendor
#
# Índice 866: Santa Bárbara
#
# Índice 873: Santo Antônio do Rio Abaixo
#
# Índice 875: Botumirim
#
#     Colisão -> Pirapetinga
#
# Índice 877: Novorizonte
#
# Índice 878: São Thomé das Letras
#
# Índice 884: Córrego Fundo
#
# Índice 885: Carmo do Cajuru
#
# Índice 887: Arantina
#
# Índice 890: Urucânia
#
# Índice 894: Aimorés
#
# Índice 895: Itaúna
#
# Índice 896: São José do Jacuri
#
# Índice 898: Paraguaçu
#
# Índice 900: Santa Margarida
#
# Índice 903: Liberdade
#
# Índice 907: Martinho Campos
#
#     Colisão -> São João do Manhuaçu
#
# Índice 908: Fortuna de Minas
#
# Índice 912: Congonhas
#
# Índice 913: Brasília de Minas
#
#     Colisão -> Fernandes Tourinho
#
# Índice 921: Pedras de Maria da Cruz
#
# Índice 923: Claro dos Poções
#
# Índice 924: Bertópolis
#
# Índice 928: Capetinga
#
# Índice 929: Senador Cortes
#
# Índice 933: Pedro Leopoldo
#
#     Colisão -> Rio Paranaíba
#
# Índice 936: Carmo de Minas
#
# Índice 941: Sarzedo
#
# Índice 943: Arinos
#
#     Colisão -> Lajinha
#
#     Colisão -> Espinosa
#
# Índice 944: Catas Altas da Noruega
#
# Índice 945: São Bento Abade
#
# Índice 946: Itapagipe
#
# Índice 951: Aguanil
#
# Índice 952: Inimutaba
#
# Índice 955: Extrema
#
# Índice 956: Santa Maria do Salto
#
#     Colisão -> Serra da Saudade
#
# Índice 959: Lavras
#
# Índice 960: Perdigão
#
# Índice 964: Rubelita
#
# Índice 965: Brumadinho
#
#     Colisão -> Juruaia
#
# Índice 966: Curral de Dentro
#
# Índice 970: Águas Formosas
#
#     Colisão -> Urucuia
#
#     Colisão -> Santana do Garambéu
#
# Índice 975: Barbacena
#
# Índice 976: Aiuruoca
#
#     Colisão -> São José da Safira
#
#     Colisão -> Canaã
#
# Índice 977: Riacho dos Machados
#
# Índice 978: Cambuquira
#
# Índice 979: Juiz de Fora
#
# Índice 981: Santa Rita do Itueto
#
#     Colisão -> Santana do Manhuaçu
#
# Índice 986: Iturama
#
# Índice 990: Itacambira
#
# Índice 991: Montezuma
#
# Índice 993: Lamim
#
# Índice 995: Jordânia
#
# Índice 996: Pedra Bonita
#
# Índice 997: São Pedro dos Ferros
#
# Índice 998: Ingaí
#
# Índice 999: Buritizeiro
#
# Índice 1002: Bom Jesus do Galho
#
# Índice 1003: Mário Campos
#
# Índice 1005: Quartel Geral
#
# Índice 1006: Carneirinho
#
#     Colisão -> Teixeiras
#
# Índice 1007: Reduto
#
# Índice 1008: Ibitiúra de Minas
#
# Índice 1012: Monjolos
#
# Índice 1016: Vazante
#
#     Colisão -> Virgem da Lapa
#
# Índice 1018: Santo Antônio do Aventureiro
#
# Índice 1021: Olhos-d'Água
#
# Índice 1025: Camanducaia
#
# Índice 1026: Santo Antônio do Jacinto
#
#     Colisão -> Sardoá
#
# Índice 1027: Mercês
#
# Índice 1028: Boa Esperança
#
# Índice 1029: Aricanduva
#
#     Colisão -> Itabirito
#
# Índice 1030: Pedra Azul
#
# Índice 1032: Presidente Olegário
#
# Índice 1038: Guarda-Mor
#
#     Colisão -> São Gonçalo do Abaeté
#
# Índice 1039: Rio Piracicaba
#
# Índice 1042: Santa Bárbara do Leste
#
# Índice 1043: Esmeraldas
#
# Índice 1045: Francisco Badaró
#
# Índice 1047: São Sebastião do Rio Preto
#
# Índice 1050: Guaraciaba
#
# Índice 1051: Chiador
#
# Índice 1053: Carbonita
#
#     Colisão -> Paracatu
#
# Índice 1056: Dores do Indaiá
#
# Índice 1057: Timóteo
#
# Índice 1059: Engenheiro Navarro
#
# Índice 1060: Ouro Branco
#
# Índice 1061: Jaguaraçu
#
# Índice 1063: Entre Folhas
#
# Índice 1065: Nazareno
#
# Índice 1066: Cabo Verde
#
#     Colisão -> Goianá
#
# Índice 1072: Alvarenga
#
# Índice 1074: Itamarandiba
#
# Índice 1077: Miraí
#
#     Colisão -> Muzambinho
#
# Índice 1078: Belo Oriente
#
#     Colisão -> Coroaci
#
# Índice 1080: Itueta
#
# Índice 1086: Carrancas
#
# Índice 1088: Rodeiro
#
#     Colisão -> São Domingos das Dores
#
# Índice 1094: Itapeva
#
# Índice 1096: Jacuí
#
# Índice 1097: Rio Vermelho
#
# Índice 1098: Caranaíba
#
# Índice 1099: Ibertioga
#
# Índice 1104: Santa Helena de Minas
#
# Índice 1106: Carvalhos
#
# Índice 1108: São José do Divino
#
# Índice 1109: Itatiaiuçu
#
# Índice 1112: Alfenas
#
#     Colisão -> Limeira do Oeste
#
# Índice 1122: Alfredo Vasconcelos
#
#     Colisão -> Galileia
#
# Índice 1125: Onça de Pitangui
#
# Índice 1126: Santos Dumont
#
# Índice 1131: Mateus Leme
#
# Índice 1132: Varginha
#
# Índice 1135: Conceição do Rio Verde
#
# Índice 1136: Sem-Peixe
#
# Índice 1138: Bela Vista de Minas
#
#     Colisão -> Capinópolis
#
# Índice 1144: Fronteira dos Vales
#
#     Colisão -> Tombos
#
# Índice 1146: Nova Era
#
# Índice 1147: Imbé de Minas
#
# Índice 1150: Estrela Dalva
#
#     Colisão -> Piedade de Caratinga
#
# Índice 1151: Cônego Marinho
#
# Índice 1152: Santa Rosa da Serra
#
# Índice 1156: Carmésia
#
#     Colisão -> Mamonas
#
# Índice 1163: Desterro do Melo
#
# Índice 1164: Alto Caparaó
#
#     Colisão -> Piedade do Rio Grande
#
#     Colisão -> Ilicínea
#
# Índice 1165: São João da Mata
#
# Índice 1169: Prudente de Morais
#
#     Colisão -> Turvolândia
#
# Índice 1172: Baependi
#
#     Colisão -> Varzelândia
#
#     Colisão -> Paiva
#
# Índice 1177: São Gonçalo do Rio Preto
#
# Índice 1178: Frei Gaspar
#
# Índice 1180: Almenara
#
#     Colisão -> Caputira
#
# Índice 1183: Goiabeira
#
#     Colisão -> Santa Cruz do Escalvado
#
# Índice 1184: Nova Ponte
#
# Índice 1186: Pedro Teixeira
#
# Índice 1189: Bom Jesus da Penha
#
# Índice 1192: Ibirité
#
# Índice 1193: Medeiros
#
# Índice 1194: Monte Santo de Minas
#
# Índice 1197: São Francisco
#
# Índice 1208: Igaratinga
#
# Índice 1210: Lagoa da Prata
#
# Índice 1212: Delfinópolis
#
# Índice 1215: Cambuí
#
# Índice 1218: Angelândia
#
# Índice 1219: Conceição dos Ouros
#
#     Colisão -> Taquaraçu de Minas
#
#     Colisão -> Morada Nova de Minas
#
# Índice 1221: Três Marias
#
# Índice 1222: Catuji
#
# Índice 1223: Serra Azul de Minas
#
# Índice 1225: Brasilândia de Minas
#
# Índice 1226: Veríssimo
#
# Índice 1228: Virginópolis
#
# Índice 1229: Mata Verde
#
#     Colisão -> Tiradentes
#
# Índice 1233: São Sebastião do Paraíso
#
# Índice 1234: Campestre
#
# Índice 1236: Monte Azul
#
# Índice 1239: Seritinga
#
# Índice 1240: Conceição do Pará
#
# Índice 1246: Couto de Magalhães de Minas
#
# Índice 1247: Santa Maria de Itabira
#
# Índice 1248: Ipiaçu
#
# Índice 1249: Orizânia
#
# Índice 1251: Lassance
#
# Índice 1256: Curvelo
#
# Índice 1262: Marmelópolis
#
#     Colisão -> Serranos
#
# Índice 1270: Vespasiano
#
# Índice 1273: Bicas
#
# Índice 1274: Alpercata
#
#     Colisão -> Dores do Turvo
#
# Índice 1277: Guiricema
#
# Índice 1280: Aracitaba
#
# Índice 1282: Rio Casca
#
# Índice 1283: Rosário da Limeira
#
#     Colisão -> São José da Barra
#
# Índice 1284: Ipuiúna
#
# Índice 1287: Abre-Campo
#
# Índice 1288: Tapira
#
# Índice 1289: Pouso Alegre
#
# Índice 1291: São José da Varginha
#
# Índice 1293: São Francisco de Paula
#
# Índice 1297: Ipanema
#
# Índice 1302: Monsenhor Paulo
#
# Índice 1304: Itamogi
#
# Índice 1314: Divinolândia de Minas
#
# Índice 1315: Ervália
#
# Índice 1317: São Tomás de Aquino
#
# Índice 1318: Cássia
#
# Índice 1322: Maravilhas
#
# Índice 1331: Santo Antônio do Monte
#
# Índice 1333: Oratórios
#
# Índice 1336: Manhumirim
#
#     Colisão -> Pequi
#
# Índice 1337: Papagaios
#
# Índice 1346: Monte Belo
#
# Índice 1347: Pirapora
#
# Índice 1353: Coronel Murta
#
# Índice 1355: Crucilândia
#
# Índice 1356: Pedra do Anta
#
# Índice 1358: Durandé
#
# Índice 1362: Buritis
#
# Índice 1363: Leopoldina
#
# Índice 1367: Doresópolis
#
# Índice 1368: Caxambu
#
# Índice 1369: Astolfo Dutra
#
#     Colisão -> Dona Eusébia
#
# Índice 1371: Machado
#
# Índice 1372: Coromandel
#
#     Colisão -> Umburatiba
#
#     Colisão -> Dom Cavati
#
# Índice 1375: Varjão de Minas
#
# Índice 1380: Claraval
#
# Índice 1387: Candeias
#
# Índice 1388: Tapiraí
#
# Índice 1395: Dom Viçoso
#
#     Colisão -> São Gotardo
#
# Índice 1398: Munhoz
#
#     Colisão -> Porteirinha
#
# Índice 1401: Cachoeira da Prata
#
#     Colisão -> Morro da Garça
#
# Índice 1405: Alagoa
#
# Índice 1413: Planura
#
#     Colisão -> Vieiras
#
# Índice 1415: Campos Gerais
#
#     Colisão -> Jequeri
#
# Índice 1416: Pains
#
# Índice 1417: Buenópolis
#
#     Colisão -> Marliéria
#
# Índice 1419: Araponga
#
#     Colisão -> Caeté
#
# Índice 1420: Itambacuri
#
# Índice 1421: Dores de Guanhães
#
# Índice 1425: Coqueiral
#
#     Colisão -> Senador Amaral
#
#     Colisão -> Jesuânia
#
# Índice 1427: Santa Rita do Sapucaí
#
# Índice 1429: Minduri
#
# Índice 1431: Brás Pires
#
#     Colisão -> Verdelândia
#
# Índice 1439: João Monlevade
#
# Índice 1441: Cristália
#
#     Colisão -> Piau
#
# Índice 1443: Capitão Andrade
#
# Índice 1446: Santo Antônio do Amparo
#
# Índice 1448: Grupiara
#
# Índice 1450: São João do Paraíso
#
# Índice 1451: Conselheiro Pena
#
# Índice 1452: Ritápolis
#
# Índice 1456: Francisco Sá
#
# Índice 1464: Cedro do Abaeté
#
# Índice 1465: Arceburgo
#
# Índice 1468: Miravânia
#
#     Colisão -> Sapucaí-Mirim
#
# Índice 1470: Madre de Deus de Minas
#
# Índice 1476: Delfim Moreira
#
#     Colisão -> Nova União
#
# Índice 1482: Japonvar
#
#     Colisão -> São Vicente de Minas
#
# Índice 1485: Rio Manso
#
# Índice 1489: Tocantins
#
# Índice 1490: Bias Fortes
#
# Índice 1497: Cachoeira de Minas
#
# Índice 1503: Itamonte
#
# Índice 1504: São Brás do Suaçuí
#
# Índice 1507: Pintópolis
#
# Índice 1510: Paula Cândido
#
# Índice 1511: Frei Inocêncio
#
# Índice 1514: Chácara
#
# Índice 1517: Gouveia
#
# Índice 1519: Capelinha
#
# Índice 1520: Ewbank da Câmara
#
# Índice 1521: Santo Antônio do Retiro
#
# Índice 1522: Leandro Ferreira
#
# Índice 1524: Guanhães
#
#     Colisão -> Ouro Preto
#
# Índice 1526: Maria da Fé
#
# Índice 1528: São Lourenço
#
# Índice 1529: Cana Verde
#
# Índice 1533: Córrego do Bom Jesus
#
#     Colisão -> Joanésia
#
#     Colisão -> Itaverava
#
# Índice 1534: Lagoa Formosa
#
# Índice 1537: Araporã
#
# Índice 1542: Resende Costa
#
# Índice 1543: Lambari
#
# Índice 1545: Cuparaque
#
#     Colisão -> Grão Mogol
#
# Índice 1547: Senador José Bento
#
# Índice 1548: Bugre
#
#     Colisão -> Manga
#
#     Colisão -> João Pinheiro
#
# Índice 1551: Governador Valadares
#
# Índice 1555: Carmo do Paranaíba
#
#     Colisão -> Joaíma
#
# Índice 1560: Piracema
#
#     Colisão -> São Félix de Minas
#
# Índice 1561: Araújos
#
#     Colisão -> Taparuba
#
# Índice 1562: Betim
#
# Índice 1568: Bambuí
#
# Índice 1570: Ituiutaba
#
# Índice 1572: Dom Joaquim
#
# Índice 1576: Juramento
#
# Índice 1578: Barão de Monte Alto
#
# Índice 1581: Gameleiras
#
# Índice 1582: Felício dos Santos
#
#     Colisão -> Ponto dos Volantes
#
# Índice 1584: Açucena
#
#     Colisão -> Tumiritinga
#
# Índice 1585: Natalândia
#
# Índice 1586: Santana de Cataguases
#
# Índice 1588: Serranópolis de Minas
#
# Índice 1594: Pouso Alto
#
# Índice 1598: Santo Antônio do Itambé
#
# Índice 1599: Casa Grande
#
#     Colisão -> São Roque de Minas
#
#     Colisão -> Fervedouro
#
# Índice 1606: Volta Grande
#
# Índice 1607: Januária
#
#     Colisão -> Presidente Kubitschek
#
# Índice 1609: Barroso
#
# Índice 1615: Pedra do Indaiá
#
# Índice 1617: Ubaporanga
#
# Índice 1621: São João Batista do Glória
#
# Índice 1622: Belo Vale
#
#     Colisão -> Olaria
#
# Índice 1624: Ouro Fino
#
#     Colisão -> Palmópolis
#
# Índice 1625: Nanuque
#
# Índice 1626: Chapada Gaúcha
#
# Índice 1629: Uruana de Minas
#
# Índice 1631: Faria Lemos
#
#     Colisão -> Itanhomi
#
# Índice 1632: Carmo da Mata
#
# Índice 1634: Frutal
#
# Índice 1638: Capela Nova
#
# Índice 1639: Estrela do Indaiá
#
# Índice 1643: Camacho
#
#     Colisão -> Indaiabira
#
# Índice 1647: Divisópolis
#
# Índice 1649: Coimbra
#
# Índice 1650: Felisburgo
#
# Índice 1657: Congonhas do Norte
#
#     Colisão -> Prados
#
# Índice 1658: Serra do Salitre
#
# Índice 1661: Sobrália
#
# Índice 1662: Itapecerica
#
# Índice 1663: Cajuri
#
# Índice 1666: Lagoa Grande
#
# Índice 1667: Catuti
#
# Índice 1677: Santana do Paraíso
#
# Índice 1680: Formoso
#
#     Colisão -> Indianópolis
#
# Índice 1684: Sacramento
#
# Índice 1685: Rochedo de Minas
#
# Índice 1688: Três Pontas
#
# Índice 1689: Coração de Jesus
#
# Índice 1692: Franciscópolis
#
# Índice 1693: Amparo da Serra
#
# Índice 1697: Ubá
#
# Índice 1699: Arcos
#
# Índice 1700: Funilândia
#
# Índice 1703: Córrego Novo
#
# Índice 1705: Jequitibá
#
# Índice 1707: Carlos Chagas
#
# Índice 1717: Rio Acima
#
# Índice 1720: Cipotânea
#
#     Colisão -> Pedralva
#
# Índice 1722: Luminárias
#
#     Colisão -> Patis
#
# Índice 1723: Matias Barbosa
#
# Índice 1729: Tiros
#
# Índice 1730: Senador Modestino Gonçalves
#
# Índice 1731: Areado
#
# Índice 1734: Caparaó
#
# Índice 1735: Cabeceira Grande
#
# Índice 1736: Japaraíba
#
#     Colisão -> São José do Alegre
#
#     Colisão -> Matias Cardoso
#
# Índice 1737: Alterosa
#
#     Colisão -> Caiana
#
# Índice 1738: Águas Vermelhas
#
#     Colisão -> Raul Soares
#
# Índice 1739: Medina
#
# Índice 1747: Antônio Dias
#
# Índice 1748: Rio Doce
#
# Índice 1750: Manhuaçu
#
# Índice 1754: Biquinhas
#
# Índice 1755: Santo Antônio do Grama
#
# Índice 1758: Santana do Jacaré
#
# Índice 1759: Divino das Laranjeiras
#
# Índice 1760: Campo do Meio
#
#     Colisão -> São Tiago
#
# Índice 1765: Luisburgo
#
# Índice 1766: Caraí
#
# Índice 1768: Veredinha
#
# Índice 1772: Jaíba
#
#     Colisão -> Muriaé
#
# Índice 1775: Guaranésia
#
# Índice 1778: Capitólio
#
#     Colisão -> São Sebastião da Bela Vista
#
# Índice 1779: Jequitinhonha
#
#     Colisão -> Rio Pomba
#
# Índice 1780: Sabará
#
# Índice 1784: Oliveira Fortes
#
# Índice 1786: Diogo de Vasconcelos
#
# Índice 1788: Minas Novas
#
# Índice 1789: Paraopeba
#
# Índice 1790: Pai Pedro
#
# Índice 1792: Antônio Carlos
#
# Índice 1793: Maripá de Minas
#
# Índice 1794: Andrelândia
#
# Índice 1798: Jenipapo de Minas
#
#     Colisão -> Piranguçu
#
# Índice 1800: José Raydan
#
#     Colisão -> Vargem Grande do Rio Pardo
#     tamanho_tabela  colisoes  maior_lista_colisao  tempo_execucao
# 0              857       317                    6        0.005306
# 1              859       305                    4        0.004015
# 2              863       316                    4        0.003988
# 3              877       309                    4        0.002996
# 4              907       304                    4        0.002992
# 5              953       277                    5        0.003005
# 6             1709       181                    3        0.003979
# 7             1741       177                    3        0.002500
# 8             1759       173                    4        0.001994
# 9             1789       162                    3        0.001995
# 10            1801       171                    3        0.005004
